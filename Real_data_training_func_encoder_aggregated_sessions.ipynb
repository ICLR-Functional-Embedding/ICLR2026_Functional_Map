# %% [markdown]
# # Description:
# This notebook contains the functional embedding being trained on multiple subjetcs' real recordings using PSC and MSC methods and how it generalizes over held out time segments and held out channels.

# %% [markdown]
# # Import Libraries

# %%
# general libraries

from torch.utils.data import DataLoader
from scipy.io import loadmat
import plotly.io as pio
import pickle

# %%
# local libraries
from src.tools.simulation import *
from src.models.CNN_encoder import *
from src.signal.signal_processing import *
from src.pipelines.embedding_data_preparation import *
from src.utils.utils import *
from src.training.PSC_training import *
from src.training.visualize_embedding import *
from src.training.evaluation import *
from src.training.MSC_training import *

# %%
# dataset related libraries (have to replace these with your own dataset loading functions), replace with your own dataset source files
import sys
import os

directory_path = "D:/Python Projects/ICLR 2026/Dataset_Related"
sys.path.append(os.path.abspath(directory_path))
from dataset import *

# %%
# Dataset related functions and mappings
# These functions should be customized for each subject and dataset, here example functions are provided


# Define which subjects and sessions to use. subjects are keys and sessions are values
# subject_sessions = {
#     's1': ['p1'], 
#     's2': ['p1'], 
#     's3': ['p4', 'p6'], 
#     's4': ['p1', 'p2'],
#     's5': ['p1', 'p2', 'p3', 'p6', 'p7'],
#     's6': ['p1', 'p2'], 
#     's7': ['p1'], 
#     's8': ['p9'],
#     's9': ['p1', 'p2', 'p3'], 
#     's10': ['p6', 'p7', 'p8', 'p9'],
# }

# def get_true_region(subject, electrode_name, side, electrode_number, verbose=False):
#     """
#     This function defines the mapping from electrode name and contact number to true brain region for a given subject.
#     """
#     if verbose: print(f"using default arrangement for {subject}")
#     if 'GPi'.lower() in electrode_name.lower() and electrode_number in [4,5,6]:
#         return 'GPi'
#     elif 'VPLa'.lower() in electrode_name.lower() and electrode_number in [4,5,6]:
#         return 'VPla'
#     elif 'VoSTN'.lower() in electrode_name.lower() and electrode_number in [4,5,6]:
#         return 'VO'
#     elif 'VoSTN'.lower() in electrode_name.lower() and electrode_number in [1,2,3]:
#         return 'STN'
#     elif 'STN'.lower() in electrode_name.lower() and electrode_number in [4,5,6]: 
#         return 'STN'
#     elif 'VIM'.lower() in electrode_name.lower() and electrode_number in [4,5,6]:
#         return 'VIM'
#     elif 'PPN'.lower() in electrode_name.lower() and electrode_number in [1,2,3]:
#         return 'PPN'
#     elif 'VA'.lower() in electrode_name.lower() and electrode_number in [4,5,6]:
#         return 'VA'
#     elif 'VoaVop'.lower() in electrode_name.lower() and electrode_number in [4,5,6]:
#         return 'VoaVop'
#     elif 'VoaVop'.lower() in electrode_name.lower() and electrode_number in [4,5,6]:
#         return 'VoaVop'
#     else: 
#         return 'unknown'

# %% [markdown]
# # Training functional encoder on aggregated dataset including several subjects and sessions Using PSC method
# This sections creates a new dataset and adds all recording sessions and trains and evaluates a functional encoder on that dataset, using held out times (test dataset) and held out channels for evaluation.

# %%
# Check GPU
device = get_device()
print(f" Using {device}")

# ----------- Config ------------ 
# training parameters
EPOCHS = 1
DATASET_SIZE = 1000000
LEARNING_RATE = 1e-2
BATCH_SIZE = 1024

# model parameters
EMBEDDING_DIM = 32
VERSION = "v1(PSC)"
DROPOUT = 0.3

# data preparation 
SEGMENT_LENGTH = 10000 # in ms here is 10 seconds

# visualization
show_model = True
#--------------------------------


dataPath = "D:\\transfer\\micro voluntary dataset\\lfs data" # path to data folder (replace with your own data path)
experiment = "Multi session training" 
subject_counter = 0

training_segments_dict = {}
validation_segments_dict = {}
testing_segments_dict = {}
held_out_channels_dict = {}

for isubject in subject_sessions.keys():
    subject_counter += 1
    for iperiod in subject_sessions[isubject]:
        print("Loading data from subject: S" + str(subject_counter) + " period: " + iperiod)
        # load microelectrode labels which contains the names of all microelectrodes in this session
        micro_electrode_path = dataPath  + os.sep + isubject + os.sep + iperiod + os.sep
        try:
            microelectrodes = load_micro_labels(micro_electrode_path + "microLabels.mat")
        except:
            mat_contents = loadmat(micro_electrode_path + "microLabels.mat")
            micro_labels = mat_contents['microLabels'] 
            microelectrodes = [str(label[0]) if isinstance(label, np.ndarray) else str(label) for label in micro_labels.squeeze()]

        
        region_electrode_count = {}
        hold_out_check = 4 # holds 1 channel out every n channels

        # Parse and print them
        for microelectrode in microelectrodes:
            region, side, electrode = parse_label(microelectrode)

            # get true region of this electrode
            true_region = get_true_region(isubject, region, side, electrode)
            if true_region != 'unknown':
                print(f"Loading {microelectrode} --> Region: {region}, Side: {side}, Electrode: {electrode} true region: {true_region}")

                # load data
                mat_path = os.path.join(micro_electrode_path, microelectrode + ".mat")
                raw_signal = None 
                try:
                    # First try HDF5 (MATLAB v7.3 format)
                    with h5py.File(mat_path, "r") as f:
                        raw_signal = np.array(f["data"]).squeeze()
                        fs = int(np.array(f["fs"]).squeeze())
                except FileNotFoundError:
                    print(f"⚠️ File not found: {mat_path}. Skipping electrode.")
                    continue  # Skip to next electrode
                except (OSError, KeyError):
                    # Fall back to standard .mat format (pre-v7.3)
                    try:
                        mat = scipy.io.loadmat(mat_path)
                        raw_signal = np.array(mat["data"]).squeeze()
                        fs = int(np.array(mat["fs"]).squeeze())
                    except Exception as e:
                        print(f"⚠️ Failed to load (not a valid .mat file): {mat_path}. Error: {e}")
                        continue  # Skip if even fallback fails

                # Remove big 60Hz artifacts
                filtered_signal = notch_filter(raw_signal,fs)

                # Normalize session recording
                normalized_signal = normalize_signal(filtered_signal)

                # Apply notch filters at 60Hz and its harmonics
                normalized_signal = notch_filter(normalized_signal,fs,freq=60)
                normalized_signal = notch_filter(normalized_signal,fs,freq=120)
                normalized_signal = notch_filter(normalized_signal,fs,freq=180)

                # Segment data into windows
                signal_segments = segment_data(normalized_signal, SEGMENT_LENGTH)

                # Skip sessions with too few segments
                if len(signal_segments) < 10:
                    print("session too short")
                    continue

                # Check if this region already has 3 electrodes, add this channel to held out channels
                region_electrode_count[true_region] = region_electrode_count.get(true_region ,0) + 1
                if region_electrode_count[true_region] % hold_out_check ==0:
                    # add to held out channel dictionary
                    if true_region in held_out_channels_dict:
                        held_out_channels_dict[true_region] = np.concat([held_out_channels_dict[true_region], signal_segments])
                    else:
                        held_out_channels_dict[true_region] = signal_segments
                else: 
                    # Split segments into training, validation, and testing sets
                    num_val = int(0.15 * len(signal_segments))
                    num_test = int(0.15 * len(signal_segments))
                    val_segments = signal_segments[:num_val]
                    test_segments = signal_segments[num_val:num_val+num_test]
                    train_segments = signal_segments[num_val+num_test:]

                    # add to training dictionary
                    if true_region in training_segments_dict:
                        training_segments_dict[true_region] = np.concat([training_segments_dict[true_region], train_segments])
                    else:
                        training_segments_dict[true_region] = train_segments

                    # add to validation dictionary
                    if true_region in validation_segments_dict:
                        validation_segments_dict[true_region] = np.concat([validation_segments_dict[true_region], val_segments])
                    else:
                        validation_segments_dict[true_region] = val_segments

                    # add to testing dictionary
                    if true_region in testing_segments_dict:
                        testing_segments_dict[true_region] = np.concat([testing_segments_dict[true_region], test_segments])
                    else:
                        testing_segments_dict[true_region] = test_segments

        # print held out channels
        print("held out channels : ", region_electrode_count)


# Shuffle segments within each region key before training
print("Shuffle segments...")
for d in [training_segments_dict, validation_segments_dict, testing_segments_dict, held_out_channels_dict]:
    for k in d:
        np.random.shuffle(d[k])

# save datasets
save_path = os.path.join("data","multi_subject_training","data_splits")
os.makedirs(save_path, exist_ok=True)
with open(os.path.join(save_path, "training_segments.pkl"), "wb") as f:
    pickle.dump(training_segments_dict, f)
with open(os.path.join(save_path, "validation_segments.pkl"), "wb") as f:
    pickle.dump(validation_segments_dict, f)
with open(os.path.join(save_path, "testing_segments.pkl"), "wb") as f:
    pickle.dump(testing_segments_dict, f)
with open(os.path.join(save_path, "heldout_channels.pkl"), "wb") as f:
    pickle.dump(held_out_channels_dict, f)


# Generate training and validation pairs for the Pairwise Siamese Contrastive (PSC) method
print("Generating training and validation pairs...")
train_pairs, train_labels = create_balanced_pairs(training_segments_dict, DATASET_SIZE)
val_pairs, val_labels = create_balanced_pairs(validation_segments_dict, min(int(0.2 * DATASET_SIZE),20000))

# Create DataLoaders
train_ds = LFPDataset(train_pairs, train_labels)
val_ds = LFPDataset(val_pairs, val_labels)
train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True)
val_loader = DataLoader(val_ds, batch_size=BATCH_SIZE)
print(f"Train set: {len(train_ds)} pairs")
print(f"Validation set: {len(val_ds)} pairs")
print(f"Batch size: {BATCH_SIZE}")

# Print shapes for sanity check
print("===== Training Input Shape Info =====")
for x1, x2, _ in train_loader:
    print(f"Train input shapes: x1: {x1.shape}, x2: {x2.shape}")
    break
print("===== Validation Input Shape Info =====")
for x1, x2, _ in val_loader:
    print(f"Validation input shapes: x1: {x1.shape}, x2: {x2.shape}\n\n")
    break

# Model setup
print("Training model...")
model = SiameseNetMultiSubject(embedding_dim=EMBEDDING_DIM,dropout=DROPOUT, normalized_output=True).to(device)
if show_model:
    print_model_summary(model, train_loader, device)
    show_model = False

# train model
save_path = os.path.join("results","multi_subject","PSC_model")
os.makedirs(save_path, exist_ok=True)
trained_model = training_validate_loop(model, train_loader, val_loader, device, save_path, EPOCHS, LEARNING_RATE)

# Extract encoder and evaluate
trained_model.eval()
encoder_model = trained_model.encoder
encoder_model.eval()

# Extract embeddings
print("Extracting embeddings...")
train_emb, train_labels_text = embed_segments_dict(training_segments_dict, encoder_model, device)
val_emb, val_labels_text = embed_segments_dict(validation_segments_dict, encoder_model, device)
test_emb, test_labels_text = embed_segments_dict(testing_segments_dict, encoder_model, device)
held_emb, held_labels_text = embed_segments_dict(held_out_channels_dict, encoder_model, device)

# KNN Evaluation
print("Extracting embeddings...")
for k in training_segments_dict:
    print(f"{k}: {len(training_segments_dict[k])} segments")

# make region balanced reference set for knn
ref_emb, ref_labels = make_balanced_reference(train_emb, train_labels_text, per_class=None, seed=42)
results_train = evaluate_knn(ref_emb, ref_labels, train_emb, train_labels_text)
results_val = evaluate_knn(ref_emb, ref_labels, val_emb, val_labels_text)
results_test = evaluate_knn(ref_emb, ref_labels, test_emb, test_labels_text)
results_held = evaluate_knn(ref_emb, ref_labels, held_emb, held_labels_text)

# Chance & clustering
print ("Computing clustering metrics...")
chance_train = compute_chance_levels(train_labels_text)
chance_val = compute_chance_levels(val_labels_text)
chance_test = compute_chance_levels(test_labels_text)    
chance_held = compute_chance_levels(held_labels_text)

metrics_train = evaluate_clustering_metrics(train_emb, train_labels_text)
metrics_val = evaluate_clustering_metrics(val_emb, val_labels_text)
metrics_test = evaluate_clustering_metrics(test_emb, test_labels_text)
metrics_held = evaluate_clustering_metrics(held_emb, held_labels_text)

# Save confusion matrix 
print("Generating and saving confusion matrices...")
plot_and_save_confusion_matrix(val_labels_text, results_val['predictions'], sorted(set(val_labels_text)), "Validation Confusion", os.path.join(save_path, "cm_val.png"))
plot_and_save_confusion_matrix(test_labels_text, results_test['predictions'], sorted(set(test_labels_text)), "Test Confusion", os.path.join(save_path, "cm_test.png"))
plot_and_save_confusion_matrix(held_labels_text, results_held['predictions'], sorted(set(held_labels_text)), "Held-Out Subject Confusion", os.path.join(save_path, "cm_heldout.png"))

# Embedding visualization
test_region_list = [label for label in test_labels_text]
test_side_list = ["" for _ in test_labels_text]
test_electrode_list = [""] * len(test_labels_text)
fig,_ = plot_interactive_embeddings(test_emb, test_region_list, test_electrode_list, test_side_list, dim=2, method='pca', metric='euclidean', show_ellipses=True, verbose=False)
pio.write_image(fig, os.path.join(save_path, f"embedding_testset_pca_2D.png"), format="png", width=950, height=700)
pio.write_json(fig,  os.path.join(save_path, f"embedding_testset_pca_2D.json"), pretty=True)

fig,_ = plot_interactive_embeddings(test_emb, test_region_list, test_electrode_list, test_side_list, dim=3, method='pca', metric='euclidean', show_ellipses=True, verbose=False)
pio.write_image(fig, os.path.join(save_path, f"embedding_testset_pca_3D.png"), format="png", width=950, height=700)
pio.write_json(fig,  os.path.join(save_path, f"embedding_testset_pca_3D.json"), pretty=True)
has_heldout = any(len(v) > 0 for v in held_out_channels_dict.values())

held_out_region_list = [label for label in held_labels_text]
held_out_side_list = ["" for _ in held_labels_text]
held_out_electrode_list = [""] * len(held_labels_text)
fig,_ = plot_interactive_embeddings(held_emb, held_out_region_list, held_out_electrode_list, held_out_side_list, dim=3, method='pca', metric='euclidean', show_ellipses=True, verbose=False)
pio.write_image(fig, os.path.join(save_path, f"embedding_heldout_pca_3D.png"), format="png", width=950, height=700)
pio.write_json(fig,  os.path.join(save_path, f"embedding_heldout_pca_3D.json"), pretty=True)


# Save results
save_evaluation_to_excel(
    subject_id="Multi-subject training",
    model_name=VERSION,
    results_train=results_train,
    results_test=results_test,
    results_heldout=results_held,
    clustering_train=metrics_train,
    clustering_test=metrics_test,
    clustering_heldout=metrics_held,
    chance_train=chance_train,
    chance_test=chance_test,
    chance_heldout=chance_held,
    save_path=os.path.join("results","multi_subject" , "evaluation_summary_multi_subject.xlsx")
)
# Out:
#  Using cuda
# Loading data from subject: S1 period: p7
# Loading microSTN_L_1_CommonFiltered_lfs --> Region: STN, Side: L, Electrode: 1 true region: STN
# Segments before cleaning: 144 | After cleaning: 118
# Loading microSTN_L_2_CommonFiltered_lfs --> Region: STN, Side: L, Electrode: 2 true region: STN
# Segments before cleaning: 144 | After cleaning: 141
# Loading microSTN_L_3_CommonFiltered_lfs --> Region: STN, Side: L, Electrode: 3 true region: STN
# Segments before cleaning: 144 | After cleaning: 78
# Loading microVoaVop_L_1_CommonFiltered_lfs --> Region: VoaVop, Side: L, Electrode: 1 true region: VO
# Segments before cleaning: 144 | After cleaning: 78
# Loading microVoaVop_L_2_CommonFiltered_lfs --> Region: VoaVop, Side: L, Electrode: 2 true region: VO
# Segments before cleaning: 144 | After cleaning: 81
# Loading microVoaVop_L_3_CommonFiltered_lfs --> Region: VoaVop, Side: L, Electrode: 3 true region: VO
# Segments before cleaning: 144 | After cleaning: 113
# Loading microSTN_R_1_CommonFiltered_lfs --> Region: STN, Side: R, Electrode: 1 true region: STN
# Segments before cleaning: 144 | After cleaning: 66
# Loading microSTN_R_2_CommonFiltered_lfs --> Region: STN, Side: R, Electrode: 2 true region: STN
# Segments before cleaning: 144 | After cleaning: 82
# Loading microSTN_R_3_CommonFiltered_lfs --> Region: STN, Side: R, Electrode: 3 true region: STN
# Segments before cleaning: 144 | After cleaning: 142
# Loading microVoaVop_R_1_CommonFiltered_lfs --> Region: VoaVop, Side: R, Electrode: 1 true region: VO
# Segments before cleaning: 144 | After cleaning: 118
# Loading microVoaVop_R_2_CommonFiltered_lfs --> Region: VoaVop, Side: R, Electrode: 2 true region: VO
# Segments before cleaning: 144 | After cleaning: 130
# Loading microVoaVop_R_3_CommonFiltered_lfs --> Region: VoaVop, Side: R, Electrode: 3 true region: VO
# Segments before cleaning: 144 | After cleaning: 124
# Loading microGPi1_L_1_CommonFiltered_lfs --> Region: GPi1, Side: L, Electrode: 1 true region: GPi
# Segments before cleaning: 144 | After cleaning: 126
# Loading microGPi1_L_2_CommonFiltered_lfs --> Region: GPi1, Side: L, Electrode: 2 true region: GPi
# Segments before cleaning: 144 | After cleaning: 143
# Loading microGPi1_L_3_CommonFiltered_lfs --> Region: GPi1, Side: L, Electrode: 3 true region: GPi
# Segments before cleaning: 144 | After cleaning: 144
# Loading microGPi1_L_4_CommonFiltered_lfs --> Region: GPi1, Side: L, Electrode: 4 true region: GPi
# Segments before cleaning: 144 | After cleaning: 138
# Loading microGPi1_L_5_CommonFiltered_lfs --> Region: GPi1, Side: L, Electrode: 5 true region: GPi
# Segments before cleaning: 144 | After cleaning: 120
# Loading microGPi1_L_6_CommonFiltered_lfs --> Region: GPi1, Side: L, Electrode: 6 true region: GPi
# Segments before cleaning: 144 | After cleaning: 96
# Loading microGPi1_R_4_CommonFiltered_lfs --> Region: GPi1, Side: R, Electrode: 4 true region: GPi
# Segments before cleaning: 144 | After cleaning: 69
# Loading microGPi1_R_5_CommonFiltered_lfs --> Region: GPi1, Side: R, Electrode: 5 true region: GPi
# Segments before cleaning: 144 | After cleaning: 99
# Loading microGPi1_R_6_CommonFiltered_lfs --> Region: GPi1, Side: R, Electrode: 6 true region: GPi
# Segments before cleaning: 144 | After cleaning: 93
# Loading microGPi1_R_7_CommonFiltered_lfs --> Region: GPi1, Side: R, Electrode: 7 true region: GPi
# Segments before cleaning: 144 | After cleaning: 75
# Loading microGPi1_R_8_CommonFiltered_lfs --> Region: GPi1, Side: R, Electrode: 8 true region: GPi
# Segments before cleaning: 144 | After cleaning: 101
# Loading microGPi2_L_4_CommonFiltered_lfs --> Region: GPi2, Side: L, Electrode: 4 true region: GPi
# Segments before cleaning: 144 | After cleaning: 96
# Loading microGPi2_L_5_CommonFiltered_lfs --> Region: GPi2, Side: L, Electrode: 5 true region: GPi
# Segments before cleaning: 144 | After cleaning: 132
# Loading microGPi2_L_6_CommonFiltered_lfs --> Region: GPi2, Side: L, Electrode: 6 true region: GPi
# Segments before cleaning: 144 | After cleaning: 131
# Loading microGPi2_R_4_CommonFiltered_lfs --> Region: GPi2, Side: R, Electrode: 4 true region: GPi
# Segments before cleaning: 144 | After cleaning: 108
# Loading microGPi2_R_5_CommonFiltered_lfs --> Region: GPi2, Side: R, Electrode: 5 true region: GPi
# Segments before cleaning: 144 | After cleaning: 113
# Loading microGPi2_R_6_CommonFiltered_lfs --> Region: GPi2, Side: R, Electrode: 6 true region: GPi
# Segments before cleaning: 144 | After cleaning: 112
# Loading microGPi2_R_7_CommonFiltered_lfs --> Region: GPi2, Side: R, Electrode: 7 true region: GPi
# Segments before cleaning: 144 | After cleaning: 108
# Loading microGPi2_R_8_CommonFiltered_lfs --> Region: GPi2, Side: R, Electrode: 8 true region: GPi
# Segments before cleaning: 144 | After cleaning: 90
# Loading microVIM_L_1_CommonFiltered_lfs --> Region: VIM, Side: L, Electrode: 1 true region: VIM
# Segments before cleaning: 144 | After cleaning: 68
# Loading microVIM_L_2_CommonFiltered_lfs --> Region: VIM, Side: L, Electrode: 2 true region: VIM
# Segments before cleaning: 144 | After cleaning: 56
# Loading microVIM_L_3_CommonFiltered_lfs --> Region: VIM, Side: L, Electrode: 3 true region: VIM
# Segments before cleaning: 144 | After cleaning: 60
# Loading microVIM_L_4_CommonFiltered_lfs --> Region: VIM, Side: L, Electrode: 4 true region: VIM
# Segments before cleaning: 144 | After cleaning: 83
# Loading microVIM_L_5_CommonFiltered_lfs --> Region: VIM, Side: L, Electrode: 5 true region: VIM
# Segments before cleaning: 144 | After cleaning: 113
# Loading microVIM_L_6_CommonFiltered_lfs --> Region: VIM, Side: L, Electrode: 6 true region: VIM
# Segments before cleaning: 144 | After cleaning: 87
# Loading microVIM_R_4_CommonFiltered_lfs --> Region: VIM, Side: R, Electrode: 4 true region: VIM
# Segments before cleaning: 144 | After cleaning: 138
# Loading microVIM_R_5_CommonFiltered_lfs --> Region: VIM, Side: R, Electrode: 5 true region: VIM
# Segments before cleaning: 144 | After cleaning: 141
# Loading microVIM_R_6_CommonFiltered_lfs --> Region: VIM, Side: R, Electrode: 6 true region: VIM
# Segments before cleaning: 144 | After cleaning: 143
# held out channels :  {'STN': 6, 'VO': 6, 'GPi': 19, 'VIM': 9}
# Loading data from subject: S1 period: p8
# Loading microSTN_L_1_CommonFiltered_lfs --> Region: STN, Side: L, Electrode: 1 true region: STN
# Segments before cleaning: 430 | After cleaning: 340
# Loading microSTN_L_2_CommonFiltered_lfs --> Region: STN, Side: L, Electrode: 2 true region: STN
# Segments before cleaning: 430 | After cleaning: 419
# Loading microSTN_L_3_CommonFiltered_lfs --> Region: STN, Side: L, Electrode: 3 true region: STN
# Segments before cleaning: 430 | After cleaning: 134
# Loading microVoaVop_L_1_CommonFiltered_lfs --> Region: VoaVop, Side: L, Electrode: 1 true region: VO
# Segments before cleaning: 430 | After cleaning: 172
# Loading microVoaVop_L_2_CommonFiltered_lfs --> Region: VoaVop, Side: L, Electrode: 2 true region: VO
# Segments before cleaning: 430 | After cleaning: 212
# Loading microVoaVop_L_3_CommonFiltered_lfs --> Region: VoaVop, Side: L, Electrode: 3 true region: VO
# Segments before cleaning: 430 | After cleaning: 332
# Loading microSTN_R_1_CommonFiltered_lfs --> Region: STN, Side: R, Electrode: 1 true region: STN
# Segments before cleaning: 430 | After cleaning: 167
# Loading microSTN_R_2_CommonFiltered_lfs --> Region: STN, Side: R, Electrode: 2 true region: STN
# Segments before cleaning: 430 | After cleaning: 205
# Loading microSTN_R_3_CommonFiltered_lfs --> Region: STN, Side: R, Electrode: 3 true region: STN
# Segments before cleaning: 430 | After cleaning: 383
# Loading microVoaVop_R_1_CommonFiltered_lfs --> Region: VoaVop, Side: R, Electrode: 1 true region: VO
# Segments before cleaning: 430 | After cleaning: 221
# Loading microVoaVop_R_2_CommonFiltered_lfs --> Region: VoaVop, Side: R, Electrode: 2 true region: VO
# Segments before cleaning: 430 | After cleaning: 283
# Loading microVoaVop_R_3_CommonFiltered_lfs --> Region: VoaVop, Side: R, Electrode: 3 true region: VO
# Segments before cleaning: 430 | After cleaning: 230
# Loading microGPi1_L_1_CommonFiltered_lfs --> Region: GPi1, Side: L, Electrode: 1 true region: GPi
# Segments before cleaning: 430 | After cleaning: 327
# Loading microGPi1_L_2_CommonFiltered_lfs --> Region: GPi1, Side: L, Electrode: 2 true region: GPi
# Segments before cleaning: 430 | After cleaning: 398
# Loading microGPi1_L_3_CommonFiltered_lfs --> Region: GPi1, Side: L, Electrode: 3 true region: GPi
# Segments before cleaning: 430 | After cleaning: 421
# Loading microGPi1_L_4_CommonFiltered_lfs --> Region: GPi1, Side: L, Electrode: 4 true region: GPi
# Segments before cleaning: 430 | After cleaning: 371
# Loading microGPi1_L_5_CommonFiltered_lfs --> Region: GPi1, Side: L, Electrode: 5 true region: GPi
# Segments before cleaning: 430 | After cleaning: 316
# Loading microGPi1_L_6_CommonFiltered_lfs --> Region: GPi1, Side: L, Electrode: 6 true region: GPi
# Segments before cleaning: 430 | After cleaning: 246
# Loading microGPi1_R_4_CommonFiltered_lfs --> Region: GPi1, Side: R, Electrode: 4 true region: GPi
# Segments before cleaning: 430 | After cleaning: 195
# Loading microGPi1_R_5_CommonFiltered_lfs --> Region: GPi1, Side: R, Electrode: 5 true region: GPi
# Segments before cleaning: 430 | After cleaning: 282
# Loading microGPi1_R_6_CommonFiltered_lfs --> Region: GPi1, Side: R, Electrode: 6 true region: GPi
# Segments before cleaning: 430 | After cleaning: 296
# Loading microGPi1_R_7_CommonFiltered_lfs --> Region: GPi1, Side: R, Electrode: 7 true region: GPi
# Segments before cleaning: 430 | After cleaning: 212
# Loading microGPi1_R_8_CommonFiltered_lfs --> Region: GPi1, Side: R, Electrode: 8 true region: GPi
# Segments before cleaning: 430 | After cleaning: 265
# Loading microGPi2_L_4_CommonFiltered_lfs --> Region: GPi2, Side: L, Electrode: 4 true region: GPi
# Segments before cleaning: 430 | After cleaning: 256
# Loading microGPi2_L_5_CommonFiltered_lfs --> Region: GPi2, Side: L, Electrode: 5 true region: GPi
# Segments before cleaning: 430 | After cleaning: 376
# Loading microGPi2_L_6_CommonFiltered_lfs --> Region: GPi2, Side: L, Electrode: 6 true region: GPi
# Segments before cleaning: 430 | After cleaning: 348
# Loading microGPi2_R_4_CommonFiltered_lfs --> Region: GPi2, Side: R, Electrode: 4 true region: GPi
# Segments before cleaning: 430 | After cleaning: 276
# Loading microGPi2_R_5_CommonFiltered_lfs --> Region: GPi2, Side: R, Electrode: 5 true region: GPi
# Segments before cleaning: 430 | After cleaning: 247
# Loading microGPi2_R_6_CommonFiltered_lfs --> Region: GPi2, Side: R, Electrode: 6 true region: GPi
# Segments before cleaning: 430 | After cleaning: 299
# Loading microGPi2_R_7_CommonFiltered_lfs --> Region: GPi2, Side: R, Electrode: 7 true region: GPi
# Segments before cleaning: 430 | After cleaning: 325
# Loading microGPi2_R_8_CommonFiltered_lfs --> Region: GPi2, Side: R, Electrode: 8 true region: GPi
# Segments before cleaning: 430 | After cleaning: 273
# Loading microVIM_L_1_CommonFiltered_lfs --> Region: VIM, Side: L, Electrode: 1 true region: VIM
# Segments before cleaning: 430 | After cleaning: 134
# Loading microVIM_L_2_CommonFiltered_lfs --> Region: VIM, Side: L, Electrode: 2 true region: VIM
# Segments before cleaning: 430 | After cleaning: 167
# Loading microVIM_L_3_CommonFiltered_lfs --> Region: VIM, Side: L, Electrode: 3 true region: VIM
# Segments before cleaning: 430 | After cleaning: 161
# Loading microVIM_L_4_CommonFiltered_lfs --> Region: VIM, Side: L, Electrode: 4 true region: VIM
# Segments before cleaning: 430 | After cleaning: 232
# Loading microVIM_L_5_CommonFiltered_lfs --> Region: VIM, Side: L, Electrode: 5 true region: VIM
# Segments before cleaning: 430 | After cleaning: 346
# Loading microVIM_L_6_CommonFiltered_lfs --> Region: VIM, Side: L, Electrode: 6 true region: VIM
# Segments before cleaning: 430 | After cleaning: 274
# Loading microVIM_R_4_CommonFiltered_lfs --> Region: VIM, Side: R, Electrode: 4 true region: VIM
# Segments before cleaning: 430 | After cleaning: 385
# Loading microVIM_R_5_CommonFiltered_lfs --> Region: VIM, Side: R, Electrode: 5 true region: VIM
# Segments before cleaning: 430 | After cleaning: 383
# Loading microVIM_R_6_CommonFiltered_lfs --> Region: VIM, Side: R, Electrode: 6 true region: VIM
# Segments before cleaning: 430 | After cleaning: 416
# held out channels :  {'STN': 6, 'VO': 6, 'GPi': 19, 'VIM': 9}
# Loading data from subject: S2 period: p2
# Loading microGPi1_L_4_CommonFiltered_lfs --> Region: GPi1, Side: L, Electrode: 4 true region: GPi
# ⚠️ Only 13 segments available. Skipping noise filtering.
# Loading microGPi1_L_5_CommonFiltered_lfs --> Region: GPi1, Side: L, Electrode: 5 true region: GPi
# ⚠️ Only 13 segments available. Skipping noise filtering.
# Loading microGPi1_L_6_CommonFiltered_lfs --> Region: GPi1, Side: L, Electrode: 6 true region: GPi
# ⚠️ Only 13 segments available. Skipping noise filtering.
# Loading microGPi1_R_4_CommonFiltered_lfs --> Region: GPi1, Side: R, Electrode: 4 true region: GPi
# ⚠️ Only 13 segments available. Skipping noise filtering.
# Loading microGPi1_R_5_CommonFiltered_lfs --> Region: GPi1, Side: R, Electrode: 5 true region: GPi
# ⚠️ Only 13 segments available. Skipping noise filtering.
# Loading microGPi1_R_6_CommonFiltered_lfs --> Region: GPi1, Side: R, Electrode: 6 true region: GPi
# ⚠️ Only 13 segments available. Skipping noise filtering.
# Loading microGPi2_L_4_CommonFiltered_lfs --> Region: GPi2, Side: L, Electrode: 4 true region: GPi
# ⚠️ Only 13 segments available. Skipping noise filtering.
# Loading microGPi2_L_5_CommonFiltered_lfs --> Region: GPi2, Side: L, Electrode: 5 true region: GPi
# ⚠️ Only 13 segments available. Skipping noise filtering.
# Loading microGPi2_L_6_CommonFiltered_lfs --> Region: GPi2, Side: L, Electrode: 6 true region: GPi
# ⚠️ Only 13 segments available. Skipping noise filtering.
# Loading microGPi2_R_4_CommonFiltered_lfs --> Region: GPi2, Side: R, Electrode: 4 true region: GPi
# ⚠️ Only 13 segments available. Skipping noise filtering.
# Loading microGPi2_R_5_CommonFiltered_lfs --> Region: GPi2, Side: R, Electrode: 5 true region: GPi
# ⚠️ Only 13 segments available. Skipping noise filtering.
# Loading microGPi2_R_6_CommonFiltered_lfs --> Region: GPi2, Side: R, Electrode: 6 true region: GPi
# ⚠️ Only 13 segments available. Skipping noise filtering.
# Loading microVA_L_4_CommonFiltered_lfs --> Region: VA, Side: L, Electrode: 4 true region: VA
# ⚠️ Only 13 segments available. Skipping noise filtering.
# Loading microVA_L_5_CommonFiltered_lfs --> Region: VA, Side: L, Electrode: 5 true region: VA
# ⚠️ Only 13 segments available. Skipping noise filtering.
# Loading microVA_L_6_CommonFiltered_lfs --> Region: VA, Side: L, Electrode: 6 true region: VA
# ⚠️ Only 13 segments available. Skipping noise filtering.
# Loading microVA_R_4_CommonFiltered_lfs --> Region: VA, Side: R, Electrode: 4 true region: VA
# ⚠️ Only 13 segments available. Skipping noise filtering.
# Loading microVA_R_5_CommonFiltered_lfs --> Region: VA, Side: R, Electrode: 5 true region: VA
# ⚠️ Only 13 segments available. Skipping noise filtering.
# Loading microVA_R_6_CommonFiltered_lfs --> Region: VA, Side: R, Electrode: 6 true region: VA
# ⚠️ Only 13 segments available. Skipping noise filtering.
# Loading microVoSTN_L_1_CommonFiltered_lfs --> Region: VoSTN, Side: L, Electrode: 1 true region: STN
# ⚠️ Only 13 segments available. Skipping noise filtering.
# Loading microVoSTN_L_2_CommonFiltered_lfs --> Region: VoSTN, Side: L, Electrode: 2 true region: STN
# ⚠️ Only 13 segments available. Skipping noise filtering.
# Loading microVoSTN_L_3_CommonFiltered_lfs --> Region: VoSTN, Side: L, Electrode: 3 true region: STN
# ⚠️ Only 13 segments available. Skipping noise filtering.
# Loading microVoSTN_L_4_CommonFiltered_lfs --> Region: VoSTN, Side: L, Electrode: 4 true region: VO
# ⚠️ Only 13 segments available. Skipping noise filtering.
# Loading microVoSTN_L_5_CommonFiltered_lfs --> Region: VoSTN, Side: L, Electrode: 5 true region: VO
# ⚠️ Only 13 segments available. Skipping noise filtering.
# Loading microVoSTN_L_6_CommonFiltered_lfs --> Region: VoSTN, Side: L, Electrode: 6 true region: VO
# ⚠️ Only 13 segments available. Skipping noise filtering.
# Loading microVoSTN_R_1_CommonFiltered_lfs --> Region: VoSTN, Side: R, Electrode: 1 true region: STN
# ⚠️ Only 13 segments available. Skipping noise filtering.
# Loading microVoSTN_R_2_CommonFiltered_lfs --> Region: VoSTN, Side: R, Electrode: 2 true region: STN
# ⚠️ Only 13 segments available. Skipping noise filtering.
# Loading microVoSTN_R_3_CommonFiltered_lfs --> Region: VoSTN, Side: R, Electrode: 3 true region: STN
# ⚠️ Only 13 segments available. Skipping noise filtering.
# Loading microVoSTN_R_4_CommonFiltered_lfs --> Region: VoSTN, Side: R, Electrode: 4 true region: VO
# ⚠️ Only 13 segments available. Skipping noise filtering.
# Loading microVoSTN_R_5_CommonFiltered_lfs --> Region: VoSTN, Side: R, Electrode: 5 true region: VO
# ⚠️ Only 13 segments available. Skipping noise filtering.
# Loading microVoSTN_R_6_CommonFiltered_lfs --> Region: VoSTN, Side: R, Electrode: 6 true region: VO
# ⚠️ Only 13 segments available. Skipping noise filtering.
# Loading microVIM_L_4_CommonFiltered_lfs --> Region: VIM, Side: L, Electrode: 4 true region: VIM
# ⚠️ Only 13 segments available. Skipping noise filtering.
# Loading microVIM_L_5_CommonFiltered_lfs --> Region: VIM, Side: L, Electrode: 5 true region: VIM
# ⚠️ Only 13 segments available. Skipping noise filtering.
# Loading microVIM_L_6_CommonFiltered_lfs --> Region: VIM, Side: L, Electrode: 6 true region: VIM
# ⚠️ Only 13 segments available. Skipping noise filtering.
# Loading microVIM_R_4_CommonFiltered_lfs --> Region: VIM, Side: R, Electrode: 4 true region: VIM
# ⚠️ Only 13 segments available. Skipping noise filtering.
# Loading microVIM_R_5_CommonFiltered_lfs --> Region: VIM, Side: R, Electrode: 5 true region: VIM
# ⚠️ Only 13 segments available. Skipping noise filtering.
# Loading microVIM_R_6_CommonFiltered_lfs --> Region: VIM, Side: R, Electrode: 6 true region: VIM
# ⚠️ Only 13 segments available. Skipping noise filtering.
# held out channels :  {'GPi': 12, 'VA': 6, 'STN': 6, 'VO': 6, 'VIM': 6}
# Loading data from subject: S2 period: p3
# Loading microGPi1_L_4_CommonFiltered_lfs --> Region: GPi1, Side: L, Electrode: 4 true region: GPi
# ⚠️ Only 50 segments available. Skipping noise filtering.
# Loading microGPi1_L_5_CommonFiltered_lfs --> Region: GPi1, Side: L, Electrode: 5 true region: GPi
# ⚠️ Only 50 segments available. Skipping noise filtering.
# Loading microGPi1_L_6_CommonFiltered_lfs --> Region: GPi1, Side: L, Electrode: 6 true region: GPi
# ⚠️ Only 50 segments available. Skipping noise filtering.
# Loading microGPi1_R_4_CommonFiltered_lfs --> Region: GPi1, Side: R, Electrode: 4 true region: GPi
# ⚠️ Only 50 segments available. Skipping noise filtering.
# Loading microGPi1_R_5_CommonFiltered_lfs --> Region: GPi1, Side: R, Electrode: 5 true region: GPi
# ⚠️ Only 50 segments available. Skipping noise filtering.
# Loading microGPi1_R_6_CommonFiltered_lfs --> Region: GPi1, Side: R, Electrode: 6 true region: GPi
# ⚠️ Only 50 segments available. Skipping noise filtering.
# Loading microGPi2_L_4_CommonFiltered_lfs --> Region: GPi2, Side: L, Electrode: 4 true region: GPi
# ⚠️ Only 50 segments available. Skipping noise filtering.
# Loading microGPi2_L_5_CommonFiltered_lfs --> Region: GPi2, Side: L, Electrode: 5 true region: GPi
# ⚠️ Only 50 segments available. Skipping noise filtering.
# Loading microGPi2_L_6_CommonFiltered_lfs --> Region: GPi2, Side: L, Electrode: 6 true region: GPi
# ⚠️ Only 50 segments available. Skipping noise filtering.
# Loading microGPi2_R_4_CommonFiltered_lfs --> Region: GPi2, Side: R, Electrode: 4 true region: GPi
# ⚠️ Only 50 segments available. Skipping noise filtering.
# Loading microGPi2_R_5_CommonFiltered_lfs --> Region: GPi2, Side: R, Electrode: 5 true region: GPi
# ⚠️ Only 50 segments available. Skipping noise filtering.
# Loading microGPi2_R_6_CommonFiltered_lfs --> Region: GPi2, Side: R, Electrode: 6 true region: GPi
# ⚠️ Only 50 segments available. Skipping noise filtering.
# Loading microVA_L_4_CommonFiltered_lfs --> Region: VA, Side: L, Electrode: 4 true region: VA
# ⚠️ Only 50 segments available. Skipping noise filtering.
# Loading microVA_L_5_CommonFiltered_lfs --> Region: VA, Side: L, Electrode: 5 true region: VA
# ⚠️ Only 50 segments available. Skipping noise filtering.
# Loading microVA_L_6_CommonFiltered_lfs --> Region: VA, Side: L, Electrode: 6 true region: VA
# ⚠️ Only 50 segments available. Skipping noise filtering.
# Loading microVA_R_4_CommonFiltered_lfs --> Region: VA, Side: R, Electrode: 4 true region: VA
# ⚠️ Only 50 segments available. Skipping noise filtering.
# Loading microVA_R_5_CommonFiltered_lfs --> Region: VA, Side: R, Electrode: 5 true region: VA
# ⚠️ Only 50 segments available. Skipping noise filtering.
# Loading microVA_R_6_CommonFiltered_lfs --> Region: VA, Side: R, Electrode: 6 true region: VA
# ⚠️ Only 50 segments available. Skipping noise filtering.
# Loading microVoSTN_L_1_CommonFiltered_lfs --> Region: VoSTN, Side: L, Electrode: 1 true region: STN
# ⚠️ Only 50 segments available. Skipping noise filtering.
# Loading microVoSTN_L_2_CommonFiltered_lfs --> Region: VoSTN, Side: L, Electrode: 2 true region: STN
# ⚠️ Only 50 segments available. Skipping noise filtering.
# Loading microVoSTN_L_3_CommonFiltered_lfs --> Region: VoSTN, Side: L, Electrode: 3 true region: STN
# ⚠️ Only 50 segments available. Skipping noise filtering.
# Loading microVoSTN_L_4_CommonFiltered_lfs --> Region: VoSTN, Side: L, Electrode: 4 true region: VO
# ⚠️ Only 50 segments available. Skipping noise filtering.
# Loading microVoSTN_L_5_CommonFiltered_lfs --> Region: VoSTN, Side: L, Electrode: 5 true region: VO
# ⚠️ Only 50 segments available. Skipping noise filtering.
# Loading microVoSTN_L_6_CommonFiltered_lfs --> Region: VoSTN, Side: L, Electrode: 6 true region: VO
# ⚠️ Only 50 segments available. Skipping noise filtering.
# Loading microVoSTN_R_1_CommonFiltered_lfs --> Region: VoSTN, Side: R, Electrode: 1 true region: STN
# ⚠️ Only 50 segments available. Skipping noise filtering.
# Loading microVoSTN_R_2_CommonFiltered_lfs --> Region: VoSTN, Side: R, Electrode: 2 true region: STN
# ⚠️ Only 50 segments available. Skipping noise filtering.
# Loading microVoSTN_R_3_CommonFiltered_lfs --> Region: VoSTN, Side: R, Electrode: 3 true region: STN
# ⚠️ Only 50 segments available. Skipping noise filtering.
# Loading microVoSTN_R_4_CommonFiltered_lfs --> Region: VoSTN, Side: R, Electrode: 4 true region: VO
# ⚠️ Only 50 segments available. Skipping noise filtering.
# Loading microVoSTN_R_5_CommonFiltered_lfs --> Region: VoSTN, Side: R, Electrode: 5 true region: VO
# ⚠️ Only 50 segments available. Skipping noise filtering.
# Loading microVoSTN_R_6_CommonFiltered_lfs --> Region: VoSTN, Side: R, Electrode: 6 true region: VO
# ⚠️ Only 50 segments available. Skipping noise filtering.
# Loading microVIM_L_4_CommonFiltered_lfs --> Region: VIM, Side: L, Electrode: 4 true region: VIM
# ⚠️ Only 50 segments available. Skipping noise filtering.
# Loading microVIM_L_5_CommonFiltered_lfs --> Region: VIM, Side: L, Electrode: 5 true region: VIM
# ⚠️ Only 50 segments available. Skipping noise filtering.
# Loading microVIM_L_6_CommonFiltered_lfs --> Region: VIM, Side: L, Electrode: 6 true region: VIM
# ⚠️ Only 50 segments available. Skipping noise filtering.
# Loading microVIM_R_4_CommonFiltered_lfs --> Region: VIM, Side: R, Electrode: 4 true region: VIM
# ⚠️ Only 50 segments available. Skipping noise filtering.
# Loading microVIM_R_5_CommonFiltered_lfs --> Region: VIM, Side: R, Electrode: 5 true region: VIM
# ⚠️ Only 50 segments available. Skipping noise filtering.
# Loading microVIM_R_6_CommonFiltered_lfs --> Region: VIM, Side: R, Electrode: 6 true region: VIM
# ⚠️ Only 50 segments available. Skipping noise filtering.
# held out channels :  {'GPi': 12, 'VA': 6, 'STN': 6, 'VO': 6, 'VIM': 6}
# Loading data from subject: S2 period: p4
# Loading microGPi1_L_4_CommonFiltered_lfs --> Region: GPi1, Side: L, Electrode: 4 true region: GPi
# ⚠️ Only 65 segments available. Skipping noise filtering.
# Loading microGPi1_L_5_CommonFiltered_lfs --> Region: GPi1, Side: L, Electrode: 5 true region: GPi
# ⚠️ Only 65 segments available. Skipping noise filtering.
# Loading microGPi1_L_6_CommonFiltered_lfs --> Region: GPi1, Side: L, Electrode: 6 true region: GPi
# ⚠️ Only 65 segments available. Skipping noise filtering.
# Loading microGPi1_R_4_CommonFiltered_lfs --> Region: GPi1, Side: R, Electrode: 4 true region: GPi
# ⚠️ Only 65 segments available. Skipping noise filtering.
# Loading microGPi1_R_5_CommonFiltered_lfs --> Region: GPi1, Side: R, Electrode: 5 true region: GPi
# ⚠️ Only 65 segments available. Skipping noise filtering.
# Loading microGPi1_R_6_CommonFiltered_lfs --> Region: GPi1, Side: R, Electrode: 6 true region: GPi
# ⚠️ Only 65 segments available. Skipping noise filtering.
# Loading microGPi2_L_4_CommonFiltered_lfs --> Region: GPi2, Side: L, Electrode: 4 true region: GPi
# ⚠️ Only 65 segments available. Skipping noise filtering.
# Loading microGPi2_L_5_CommonFiltered_lfs --> Region: GPi2, Side: L, Electrode: 5 true region: GPi
# ⚠️ Only 65 segments available. Skipping noise filtering.
# Loading microGPi2_L_6_CommonFiltered_lfs --> Region: GPi2, Side: L, Electrode: 6 true region: GPi
# ⚠️ Only 65 segments available. Skipping noise filtering.
# Loading microGPi2_R_4_CommonFiltered_lfs --> Region: GPi2, Side: R, Electrode: 4 true region: GPi
# ⚠️ Only 65 segments available. Skipping noise filtering.
# Loading microGPi2_R_5_CommonFiltered_lfs --> Region: GPi2, Side: R, Electrode: 5 true region: GPi
# ⚠️ Only 65 segments available. Skipping noise filtering.
# Loading microGPi2_R_6_CommonFiltered_lfs --> Region: GPi2, Side: R, Electrode: 6 true region: GPi
# ⚠️ Only 65 segments available. Skipping noise filtering.
# Loading microVA_L_4_CommonFiltered_lfs --> Region: VA, Side: L, Electrode: 4 true region: VA
# ⚠️ Only 65 segments available. Skipping noise filtering.
# Loading microVA_L_5_CommonFiltered_lfs --> Region: VA, Side: L, Electrode: 5 true region: VA
# ⚠️ Only 65 segments available. Skipping noise filtering.
# Loading microVA_L_6_CommonFiltered_lfs --> Region: VA, Side: L, Electrode: 6 true region: VA
# ⚠️ Only 65 segments available. Skipping noise filtering.
# Loading microVA_R_4_CommonFiltered_lfs --> Region: VA, Side: R, Electrode: 4 true region: VA
# ⚠️ Only 65 segments available. Skipping noise filtering.
# Loading microVA_R_5_CommonFiltered_lfs --> Region: VA, Side: R, Electrode: 5 true region: VA
# ⚠️ Only 65 segments available. Skipping noise filtering.
# Loading microVA_R_6_CommonFiltered_lfs --> Region: VA, Side: R, Electrode: 6 true region: VA
# ⚠️ Only 65 segments available. Skipping noise filtering.
# Loading microVoSTN_L_1_CommonFiltered_lfs --> Region: VoSTN, Side: L, Electrode: 1 true region: STN
# ⚠️ Only 65 segments available. Skipping noise filtering.
# Loading microVoSTN_L_2_CommonFiltered_lfs --> Region: VoSTN, Side: L, Electrode: 2 true region: STN
# ⚠️ Only 65 segments available. Skipping noise filtering.
# Loading microVoSTN_L_3_CommonFiltered_lfs --> Region: VoSTN, Side: L, Electrode: 3 true region: STN
# ⚠️ Only 65 segments available. Skipping noise filtering.
# Loading microVoSTN_L_4_CommonFiltered_lfs --> Region: VoSTN, Side: L, Electrode: 4 true region: VO
# ⚠️ Only 65 segments available. Skipping noise filtering.
# Loading microVoSTN_L_5_CommonFiltered_lfs --> Region: VoSTN, Side: L, Electrode: 5 true region: VO
# ⚠️ Only 65 segments available. Skipping noise filtering.
# Loading microVoSTN_L_6_CommonFiltered_lfs --> Region: VoSTN, Side: L, Electrode: 6 true region: VO
# ⚠️ Only 65 segments available. Skipping noise filtering.
# Loading microVoSTN_R_1_CommonFiltered_lfs --> Region: VoSTN, Side: R, Electrode: 1 true region: STN
# ⚠️ Only 65 segments available. Skipping noise filtering.
# Loading microVoSTN_R_2_CommonFiltered_lfs --> Region: VoSTN, Side: R, Electrode: 2 true region: STN
# ⚠️ Only 65 segments available. Skipping noise filtering.
# Loading microVoSTN_R_3_CommonFiltered_lfs --> Region: VoSTN, Side: R, Electrode: 3 true region: STN
# ⚠️ Only 65 segments available. Skipping noise filtering.
# Loading microVoSTN_R_4_CommonFiltered_lfs --> Region: VoSTN, Side: R, Electrode: 4 true region: VO
# ⚠️ Only 65 segments available. Skipping noise filtering.
# Loading microVoSTN_R_5_CommonFiltered_lfs --> Region: VoSTN, Side: R, Electrode: 5 true region: VO
# ⚠️ Only 65 segments available. Skipping noise filtering.
# Loading microVoSTN_R_6_CommonFiltered_lfs --> Region: VoSTN, Side: R, Electrode: 6 true region: VO
# ⚠️ Only 65 segments available. Skipping noise filtering.
# Loading microVIM_L_4_CommonFiltered_lfs --> Region: VIM, Side: L, Electrode: 4 true region: VIM
# ⚠️ Only 65 segments available. Skipping noise filtering.
# Loading microVIM_L_5_CommonFiltered_lfs --> Region: VIM, Side: L, Electrode: 5 true region: VIM
# ⚠️ Only 65 segments available. Skipping noise filtering.
# Loading microVIM_L_6_CommonFiltered_lfs --> Region: VIM, Side: L, Electrode: 6 true region: VIM
# ⚠️ Only 65 segments available. Skipping noise filtering.
# Loading microVIM_R_4_CommonFiltered_lfs --> Region: VIM, Side: R, Electrode: 4 true region: VIM
# ⚠️ Only 65 segments available. Skipping noise filtering.
# Loading microVIM_R_5_CommonFiltered_lfs --> Region: VIM, Side: R, Electrode: 5 true region: VIM
# ⚠️ Only 65 segments available. Skipping noise filtering.
# Loading microVIM_R_6_CommonFiltered_lfs --> Region: VIM, Side: R, Electrode: 6 true region: VIM
# ⚠️ Only 65 segments available. Skipping noise filtering.
# held out channels :  {'GPi': 12, 'VA': 6, 'STN': 6, 'VO': 6, 'VIM': 6}
# Loading data from subject: S3 period: p9
# Loading microGPi1_L_4_CommonFiltered_lfs --> Region: GPi1, Side: L, Electrode: 4 true region: GPi
# ⚠️ Only 79 segments available. Skipping noise filtering.
# Loading microGPi1_L_5_CommonFiltered_lfs --> Region: GPi1, Side: L, Electrode: 5 true region: GPi
# ⚠️ Only 79 segments available. Skipping noise filtering.
# Loading microGPi1_L_6_CommonFiltered_lfs --> Region: GPi1, Side: L, Electrode: 6 true region: GPi
# ⚠️ Only 79 segments available. Skipping noise filtering.
# Loading microGPi1_R_4_CommonFiltered_lfs --> Region: GPi1, Side: R, Electrode: 4 true region: GPi
# ⚠️ Only 79 segments available. Skipping noise filtering.
# Loading microGPi1_R_5_CommonFiltered_lfs --> Region: GPi1, Side: R, Electrode: 5 true region: GPi
# ⚠️ Only 79 segments available. Skipping noise filtering.
# Loading microGPi1_R_6_CommonFiltered_lfs --> Region: GPi1, Side: R, Electrode: 6 true region: GPi
# ⚠️ Only 79 segments available. Skipping noise filtering.
# Loading microGPi2_L_4_CommonFiltered_lfs --> Region: GPi2, Side: L, Electrode: 4 true region: GPi
# ⚠️ Only 79 segments available. Skipping noise filtering.
# Loading microGPi2_L_5_CommonFiltered_lfs --> Region: GPi2, Side: L, Electrode: 5 true region: GPi
# ⚠️ Only 79 segments available. Skipping noise filtering.
# Loading microGPi2_L_6_CommonFiltered_lfs --> Region: GPi2, Side: L, Electrode: 6 true region: GPi
# ⚠️ Only 79 segments available. Skipping noise filtering.
# Loading microGPi2_R_4_CommonFiltered_lfs --> Region: GPi2, Side: R, Electrode: 4 true region: GPi
# ⚠️ Only 79 segments available. Skipping noise filtering.
# Loading microGPi2_R_5_CommonFiltered_lfs --> Region: GPi2, Side: R, Electrode: 5 true region: GPi
# ⚠️ Only 79 segments available. Skipping noise filtering.
# Loading microGPi2_R_6_CommonFiltered_lfs --> Region: GPi2, Side: R, Electrode: 6 true region: GPi
# ⚠️ Only 79 segments available. Skipping noise filtering.
# Loading microVA_L_4_CommonFiltered_lfs --> Region: VA, Side: L, Electrode: 4 true region: VA
# ⚠️ Only 79 segments available. Skipping noise filtering.
# Loading microVA_L_5_CommonFiltered_lfs --> Region: VA, Side: L, Electrode: 5 true region: VA
# ⚠️ Only 79 segments available. Skipping noise filtering.
# Loading microVA_L_6_CommonFiltered_lfs --> Region: VA, Side: L, Electrode: 6 true region: VA
# ⚠️ Only 79 segments available. Skipping noise filtering.
# Loading microVA_R_4_CommonFiltered_lfs --> Region: VA, Side: R, Electrode: 4 true region: VA
# ⚠️ Only 79 segments available. Skipping noise filtering.
# Loading microVA_R_5_CommonFiltered_lfs --> Region: VA, Side: R, Electrode: 5 true region: VA
# ⚠️ Only 79 segments available. Skipping noise filtering.
# Loading microVA_R_6_CommonFiltered_lfs --> Region: VA, Side: R, Electrode: 6 true region: VA
# ⚠️ Only 79 segments available. Skipping noise filtering.
# Loading microVoSTN_L_1_CommonFiltered_lfs --> Region: VoSTN, Side: L, Electrode: 1 true region: STN
# ⚠️ Only 79 segments available. Skipping noise filtering.
# Loading microVoSTN_L_2_CommonFiltered_lfs --> Region: VoSTN, Side: L, Electrode: 2 true region: STN
# ⚠️ Only 79 segments available. Skipping noise filtering.
# Loading microVoSTN_L_3_CommonFiltered_lfs --> Region: VoSTN, Side: L, Electrode: 3 true region: STN
# ⚠️ Only 79 segments available. Skipping noise filtering.
# Loading microVoSTN_L_4_CommonFiltered_lfs --> Region: VoSTN, Side: L, Electrode: 4 true region: VO
# ⚠️ Only 79 segments available. Skipping noise filtering.
# Loading microVoSTN_L_5_CommonFiltered_lfs --> Region: VoSTN, Side: L, Electrode: 5 true region: VO
# ⚠️ Only 79 segments available. Skipping noise filtering.
# Loading microVoSTN_L_6_CommonFiltered_lfs --> Region: VoSTN, Side: L, Electrode: 6 true region: VO
# ⚠️ Only 79 segments available. Skipping noise filtering.
# Loading microVoSTN_R_1_CommonFiltered_lfs --> Region: VoSTN, Side: R, Electrode: 1 true region: STN
# ⚠️ Only 79 segments available. Skipping noise filtering.
# Loading microVoSTN_R_2_CommonFiltered_lfs --> Region: VoSTN, Side: R, Electrode: 2 true region: STN
# ⚠️ Only 79 segments available. Skipping noise filtering.
# Loading microVoSTN_R_3_CommonFiltered_lfs --> Region: VoSTN, Side: R, Electrode: 3 true region: STN
# ⚠️ Only 79 segments available. Skipping noise filtering.
# Loading microVoSTN_R_4_CommonFiltered_lfs --> Region: VoSTN, Side: R, Electrode: 4 true region: VO
# ⚠️ Only 79 segments available. Skipping noise filtering.
# Loading microVoSTN_R_5_CommonFiltered_lfs --> Region: VoSTN, Side: R, Electrode: 5 true region: VO
# ⚠️ Only 79 segments available. Skipping noise filtering.
# Loading microVoSTN_R_6_CommonFiltered_lfs --> Region: VoSTN, Side: R, Electrode: 6 true region: VO
# ⚠️ Only 79 segments available. Skipping noise filtering.
# Loading microVIM_L_4_CommonFiltered_lfs --> Region: VIM, Side: L, Electrode: 4 true region: VIM
# ⚠️ Only 79 segments available. Skipping noise filtering.
# Loading microVIM_L_5_CommonFiltered_lfs --> Region: VIM, Side: L, Electrode: 5 true region: VIM
# ⚠️ Only 79 segments available. Skipping noise filtering.
# Loading microVIM_L_6_CommonFiltered_lfs --> Region: VIM, Side: L, Electrode: 6 true region: VIM
# ⚠️ Only 79 segments available. Skipping noise filtering.
# Loading microVIM_R_4_CommonFiltered_lfs --> Region: VIM, Side: R, Electrode: 4 true region: VIM
# ⚠️ Only 79 segments available. Skipping noise filtering.
# Loading microVIM_R_5_CommonFiltered_lfs --> Region: VIM, Side: R, Electrode: 5 true region: VIM
# ⚠️ Only 79 segments available. Skipping noise filtering.
# Loading microVIM_R_6_CommonFiltered_lfs --> Region: VIM, Side: R, Electrode: 6 true region: VIM
# ⚠️ Only 79 segments available. Skipping noise filtering.
# held out channels :  {'GPi': 12, 'VA': 6, 'STN': 6, 'VO': 6, 'VIM': 6}
# Loading data from subject: S3 period: p10
# Loading microGPi1_L_4_CommonFiltered_lfs --> Region: GPi1, Side: L, Electrode: 4 true region: GPi
# ⚠️ Only 38 segments available. Skipping noise filtering.
# Loading microGPi1_L_5_CommonFiltered_lfs --> Region: GPi1, Side: L, Electrode: 5 true region: GPi
# ⚠️ Only 38 segments available. Skipping noise filtering.
# Loading microGPi1_L_6_CommonFiltered_lfs --> Region: GPi1, Side: L, Electrode: 6 true region: GPi
# ⚠️ Only 38 segments available. Skipping noise filtering.
# Loading microGPi1_R_4_CommonFiltered_lfs --> Region: GPi1, Side: R, Electrode: 4 true region: GPi
# ⚠️ Only 38 segments available. Skipping noise filtering.
# Loading microGPi1_R_5_CommonFiltered_lfs --> Region: GPi1, Side: R, Electrode: 5 true region: GPi
# ⚠️ Only 38 segments available. Skipping noise filtering.
# Loading microGPi1_R_6_CommonFiltered_lfs --> Region: GPi1, Side: R, Electrode: 6 true region: GPi
# ⚠️ Only 38 segments available. Skipping noise filtering.
# Loading microGPi2_L_4_CommonFiltered_lfs --> Region: GPi2, Side: L, Electrode: 4 true region: GPi
# ⚠️ Only 38 segments available. Skipping noise filtering.
# Loading microGPi2_L_5_CommonFiltered_lfs --> Region: GPi2, Side: L, Electrode: 5 true region: GPi
# ⚠️ Only 38 segments available. Skipping noise filtering.
# Loading microGPi2_L_6_CommonFiltered_lfs --> Region: GPi2, Side: L, Electrode: 6 true region: GPi
# ⚠️ Only 38 segments available. Skipping noise filtering.
# Loading microGPi2_R_4_CommonFiltered_lfs --> Region: GPi2, Side: R, Electrode: 4 true region: GPi
# ⚠️ Only 38 segments available. Skipping noise filtering.
# Loading microGPi2_R_5_CommonFiltered_lfs --> Region: GPi2, Side: R, Electrode: 5 true region: GPi
# ⚠️ Only 38 segments available. Skipping noise filtering.
# Loading microGPi2_R_6_CommonFiltered_lfs --> Region: GPi2, Side: R, Electrode: 6 true region: GPi
# ⚠️ Only 38 segments available. Skipping noise filtering.
# Loading microVA_L_4_CommonFiltered_lfs --> Region: VA, Side: L, Electrode: 4 true region: VA
# ⚠️ Only 38 segments available. Skipping noise filtering.
# Loading microVA_L_5_CommonFiltered_lfs --> Region: VA, Side: L, Electrode: 5 true region: VA
# ⚠️ Only 38 segments available. Skipping noise filtering.
# Loading microVA_L_6_CommonFiltered_lfs --> Region: VA, Side: L, Electrode: 6 true region: VA
# ⚠️ Only 38 segments available. Skipping noise filtering.
# Loading microVA_R_4_CommonFiltered_lfs --> Region: VA, Side: R, Electrode: 4 true region: VA
# ⚠️ Only 38 segments available. Skipping noise filtering.
# Loading microVA_R_5_CommonFiltered_lfs --> Region: VA, Side: R, Electrode: 5 true region: VA
# ⚠️ Only 38 segments available. Skipping noise filtering.
# Loading microVA_R_6_CommonFiltered_lfs --> Region: VA, Side: R, Electrode: 6 true region: VA
# ⚠️ Only 38 segments available. Skipping noise filtering.
# Loading microVoSTN_L_1_CommonFiltered_lfs --> Region: VoSTN, Side: L, Electrode: 1 true region: STN
# ⚠️ Only 38 segments available. Skipping noise filtering.
# Loading microVoSTN_L_2_CommonFiltered_lfs --> Region: VoSTN, Side: L, Electrode: 2 true region: STN
# ⚠️ Only 38 segments available. Skipping noise filtering.
# Loading microVoSTN_L_3_CommonFiltered_lfs --> Region: VoSTN, Side: L, Electrode: 3 true region: STN
# ⚠️ Only 38 segments available. Skipping noise filtering.
# Loading microVoSTN_L_4_CommonFiltered_lfs --> Region: VoSTN, Side: L, Electrode: 4 true region: VO
# ⚠️ Only 38 segments available. Skipping noise filtering.
# Loading microVoSTN_L_5_CommonFiltered_lfs --> Region: VoSTN, Side: L, Electrode: 5 true region: VO
# ⚠️ Only 38 segments available. Skipping noise filtering.
# Loading microVoSTN_L_6_CommonFiltered_lfs --> Region: VoSTN, Side: L, Electrode: 6 true region: VO
# ⚠️ Only 38 segments available. Skipping noise filtering.
# Loading microVoSTN_R_1_CommonFiltered_lfs --> Region: VoSTN, Side: R, Electrode: 1 true region: STN
# ⚠️ Only 38 segments available. Skipping noise filtering.
# Loading microVoSTN_R_2_CommonFiltered_lfs --> Region: VoSTN, Side: R, Electrode: 2 true region: STN
# ⚠️ Only 38 segments available. Skipping noise filtering.
# Loading microVoSTN_R_3_CommonFiltered_lfs --> Region: VoSTN, Side: R, Electrode: 3 true region: STN
# ⚠️ Only 38 segments available. Skipping noise filtering.
# Loading microVoSTN_R_4_CommonFiltered_lfs --> Region: VoSTN, Side: R, Electrode: 4 true region: VO
# ⚠️ Only 38 segments available. Skipping noise filtering.
# Loading microVoSTN_R_5_CommonFiltered_lfs --> Region: VoSTN, Side: R, Electrode: 5 true region: VO
# ⚠️ Only 38 segments available. Skipping noise filtering.
# Loading microVoSTN_R_6_CommonFiltered_lfs --> Region: VoSTN, Side: R, Electrode: 6 true region: VO
# ⚠️ Only 38 segments available. Skipping noise filtering.
# Loading microVIM_L_4_CommonFiltered_lfs --> Region: VIM, Side: L, Electrode: 4 true region: VIM
# ⚠️ Only 38 segments available. Skipping noise filtering.
# Loading microVIM_L_5_CommonFiltered_lfs --> Region: VIM, Side: L, Electrode: 5 true region: VIM
# ⚠️ Only 38 segments available. Skipping noise filtering.
# Loading microVIM_L_6_CommonFiltered_lfs --> Region: VIM, Side: L, Electrode: 6 true region: VIM
# ⚠️ Only 38 segments available. Skipping noise filtering.
# Loading microVIM_R_4_CommonFiltered_lfs --> Region: VIM, Side: R, Electrode: 4 true region: VIM
# ⚠️ Only 38 segments available. Skipping noise filtering.
# Loading microVIM_R_5_CommonFiltered_lfs --> Region: VIM, Side: R, Electrode: 5 true region: VIM
# ⚠️ Only 38 segments available. Skipping noise filtering.
# Loading microVIM_R_6_CommonFiltered_lfs --> Region: VIM, Side: R, Electrode: 6 true region: VIM
# ⚠️ Only 38 segments available. Skipping noise filtering.
# held out channels :  {'GPi': 12, 'VA': 6, 'STN': 6, 'VO': 6, 'VIM': 6}
# Loading data from subject: S3 period: p11
# Loading microGPi1_L_4_CommonFiltered_lfs --> Region: GPi1, Side: L, Electrode: 4 true region: GPi
# ⚠️ Only 16 segments available. Skipping noise filtering.
# Loading microGPi1_L_5_CommonFiltered_lfs --> Region: GPi1, Side: L, Electrode: 5 true region: GPi
# ⚠️ Only 16 segments available. Skipping noise filtering.
# Loading microGPi1_L_6_CommonFiltered_lfs --> Region: GPi1, Side: L, Electrode: 6 true region: GPi
# ⚠️ Only 16 segments available. Skipping noise filtering.
# Loading microGPi1_R_4_CommonFiltered_lfs --> Region: GPi1, Side: R, Electrode: 4 true region: GPi
# ⚠️ Only 16 segments available. Skipping noise filtering.
# Loading microGPi1_R_5_CommonFiltered_lfs --> Region: GPi1, Side: R, Electrode: 5 true region: GPi
# ⚠️ Only 16 segments available. Skipping noise filtering.
# Loading microGPi1_R_6_CommonFiltered_lfs --> Region: GPi1, Side: R, Electrode: 6 true region: GPi
# ⚠️ Only 16 segments available. Skipping noise filtering.
# Loading microGPi2_L_4_CommonFiltered_lfs --> Region: GPi2, Side: L, Electrode: 4 true region: GPi
# ⚠️ Only 16 segments available. Skipping noise filtering.
# Loading microGPi2_L_5_CommonFiltered_lfs --> Region: GPi2, Side: L, Electrode: 5 true region: GPi
# ⚠️ Only 16 segments available. Skipping noise filtering.
# Loading microGPi2_L_6_CommonFiltered_lfs --> Region: GPi2, Side: L, Electrode: 6 true region: GPi
# ⚠️ Only 16 segments available. Skipping noise filtering.
# Loading microGPi2_R_4_CommonFiltered_lfs --> Region: GPi2, Side: R, Electrode: 4 true region: GPi
# ⚠️ Only 16 segments available. Skipping noise filtering.
# Loading microGPi2_R_5_CommonFiltered_lfs --> Region: GPi2, Side: R, Electrode: 5 true region: GPi
# ⚠️ Only 16 segments available. Skipping noise filtering.
# Loading microGPi2_R_6_CommonFiltered_lfs --> Region: GPi2, Side: R, Electrode: 6 true region: GPi
# ⚠️ Only 16 segments available. Skipping noise filtering.
# Loading microVA_L_4_CommonFiltered_lfs --> Region: VA, Side: L, Electrode: 4 true region: VA
# ⚠️ Only 16 segments available. Skipping noise filtering.
# Loading microVA_L_5_CommonFiltered_lfs --> Region: VA, Side: L, Electrode: 5 true region: VA
# ⚠️ Only 16 segments available. Skipping noise filtering.
# Loading microVA_L_6_CommonFiltered_lfs --> Region: VA, Side: L, Electrode: 6 true region: VA
# ⚠️ Only 16 segments available. Skipping noise filtering.
# Loading microVA_R_4_CommonFiltered_lfs --> Region: VA, Side: R, Electrode: 4 true region: VA
# ⚠️ Only 16 segments available. Skipping noise filtering.
# Loading microVA_R_5_CommonFiltered_lfs --> Region: VA, Side: R, Electrode: 5 true region: VA
# ⚠️ Only 16 segments available. Skipping noise filtering.
# Loading microVA_R_6_CommonFiltered_lfs --> Region: VA, Side: R, Electrode: 6 true region: VA
# ⚠️ Only 16 segments available. Skipping noise filtering.
# Loading microVoSTN_L_1_CommonFiltered_lfs --> Region: VoSTN, Side: L, Electrode: 1 true region: STN
# ⚠️ Only 16 segments available. Skipping noise filtering.
# Loading microVoSTN_L_2_CommonFiltered_lfs --> Region: VoSTN, Side: L, Electrode: 2 true region: STN
# ⚠️ Only 16 segments available. Skipping noise filtering.
# Loading microVoSTN_L_3_CommonFiltered_lfs --> Region: VoSTN, Side: L, Electrode: 3 true region: STN
# ⚠️ Only 16 segments available. Skipping noise filtering.
# Loading microVoSTN_L_4_CommonFiltered_lfs --> Region: VoSTN, Side: L, Electrode: 4 true region: VO
# ⚠️ Only 16 segments available. Skipping noise filtering.
# Loading microVoSTN_L_5_CommonFiltered_lfs --> Region: VoSTN, Side: L, Electrode: 5 true region: VO
# ⚠️ Only 16 segments available. Skipping noise filtering.
# Loading microVoSTN_L_6_CommonFiltered_lfs --> Region: VoSTN, Side: L, Electrode: 6 true region: VO
# ⚠️ Only 16 segments available. Skipping noise filtering.
# Loading microVoSTN_R_1_CommonFiltered_lfs --> Region: VoSTN, Side: R, Electrode: 1 true region: STN
# ⚠️ Only 16 segments available. Skipping noise filtering.
# Loading microVoSTN_R_2_CommonFiltered_lfs --> Region: VoSTN, Side: R, Electrode: 2 true region: STN
# ⚠️ Only 16 segments available. Skipping noise filtering.
# Loading microVoSTN_R_3_CommonFiltered_lfs --> Region: VoSTN, Side: R, Electrode: 3 true region: STN
# ⚠️ Only 16 segments available. Skipping noise filtering.
# Loading microVoSTN_R_4_CommonFiltered_lfs --> Region: VoSTN, Side: R, Electrode: 4 true region: VO
# ⚠️ Only 16 segments available. Skipping noise filtering.
# Loading microVoSTN_R_5_CommonFiltered_lfs --> Region: VoSTN, Side: R, Electrode: 5 true region: VO
# ⚠️ Only 16 segments available. Skipping noise filtering.
# Loading microVoSTN_R_6_CommonFiltered_lfs --> Region: VoSTN, Side: R, Electrode: 6 true region: VO
# ⚠️ Only 16 segments available. Skipping noise filtering.
# Loading microVIM_L_4_CommonFiltered_lfs --> Region: VIM, Side: L, Electrode: 4 true region: VIM
# ⚠️ Only 16 segments available. Skipping noise filtering.
# Loading microVIM_L_5_CommonFiltered_lfs --> Region: VIM, Side: L, Electrode: 5 true region: VIM
# ⚠️ Only 16 segments available. Skipping noise filtering.
# Loading microVIM_L_6_CommonFiltered_lfs --> Region: VIM, Side: L, Electrode: 6 true region: VIM
# ⚠️ Only 16 segments available. Skipping noise filtering.
# Loading microVIM_R_4_CommonFiltered_lfs --> Region: VIM, Side: R, Electrode: 4 true region: VIM
# ⚠️ Only 16 segments available. Skipping noise filtering.
# Loading microVIM_R_5_CommonFiltered_lfs --> Region: VIM, Side: R, Electrode: 5 true region: VIM
# ⚠️ Only 16 segments available. Skipping noise filtering.
# Loading microVIM_R_6_CommonFiltered_lfs --> Region: VIM, Side: R, Electrode: 6 true region: VIM
# ⚠️ Only 16 segments available. Skipping noise filtering.
# held out channels :  {'GPi': 12, 'VA': 6, 'STN': 6, 'VO': 6, 'VIM': 6}
# Loading data from subject: S4 period: p4
# Loading microGPi1_L_4_CommonFiltered_lfs --> Region: GPi1, Side: L, Electrode: 4 true region: GPi
# ⚠️ Only 40 segments available. Skipping noise filtering.
# Loading microGPi1_L_5_CommonFiltered_lfs --> Region: GPi1, Side: L, Electrode: 5 true region: GPi
# ⚠️ Only 40 segments available. Skipping noise filtering.
# Loading microGPi1_L_6_CommonFiltered_lfs --> Region: GPi1, Side: L, Electrode: 6 true region: GPi
# ⚠️ Only 40 segments available. Skipping noise filtering.
# Loading microGPi1_R_4_CommonFiltered_lfs --> Region: GPi1, Side: R, Electrode: 4 true region: GPi
# ⚠️ Only 40 segments available. Skipping noise filtering.
# Loading microGPi1_R_5_CommonFiltered_lfs --> Region: GPi1, Side: R, Electrode: 5 true region: GPi
# ⚠️ Only 40 segments available. Skipping noise filtering.
# Loading microGPi1_R_6_CommonFiltered_lfs --> Region: GPi1, Side: R, Electrode: 6 true region: GPi
# ⚠️ Only 40 segments available. Skipping noise filtering.
# Loading microGPi2_L_4_CommonFiltered_lfs --> Region: GPi2, Side: L, Electrode: 4 true region: GPi
# ⚠️ Only 40 segments available. Skipping noise filtering.
# Loading microGPi2_L_5_CommonFiltered_lfs --> Region: GPi2, Side: L, Electrode: 5 true region: GPi
# ⚠️ Only 40 segments available. Skipping noise filtering.
# Loading microGPi2_L_6_CommonFiltered_lfs --> Region: GPi2, Side: L, Electrode: 6 true region: GPi
# ⚠️ Only 40 segments available. Skipping noise filtering.
# Loading microGPi2_R_4_CommonFiltered_lfs --> Region: GPi2, Side: R, Electrode: 4 true region: GPi
# ⚠️ Only 40 segments available. Skipping noise filtering.
# Loading microGPi2_R_5_CommonFiltered_lfs --> Region: GPi2, Side: R, Electrode: 5 true region: GPi
# ⚠️ Only 40 segments available. Skipping noise filtering.
# ...
# ⚠️ Only 41 segments available. Skipping noise filtering.
# Loading microVOSTN_R_2_CommonFiltered_lfs --> Region: VOSTN, Side: R, Electrode: 2 true region: STN
# ⚠️ Only 41 segments available. Skipping noise filtering.
# Loading microVOSTN_R_3_CommonFiltered_lfs --> Region: VOSTN, Side: R, Electrode: 3 true region: STN
# ⚠️ Only 41 segments available. Skipping noise filtering.
# Loading microVOSTN_R_4_CommonFiltered_lfs --> Region: VOSTN, Side: R, Electrode: 4 true region: STN
# ⚠️ Only 41 segments available. Skipping noise filtering.
# Loading microVOSTN_R_5_CommonFiltered_lfs --> Region: VOSTN, Side: R, Electrode: 5 true region: STN
# ⚠️ Only 41 segments available. Skipping noise filtering.
# Loading microVOSTN_R_6_CommonFiltered_lfs --> Region: VOSTN, Side: R, Electrode: 6 true region: STN
# ⚠️ Only 41 segments available. Skipping noise filtering.
# Loading microVOSTN_R_7_CommonFiltered_lfs --> Region: VOSTN, Side: R, Electrode: 7 true region: VO
# ⚠️ Only 41 segments available. Skipping noise filtering.
# Loading microVOSTN_R_8_CommonFiltered_lfs --> Region: VOSTN, Side: R, Electrode: 8 true region: VO
# ⚠️ Only 41 segments available. Skipping noise filtering.
# Loading microVOSTN_R_9_CommonFiltered_lfs --> Region: VOSTN, Side: R, Electrode: 9 true region: VO
# ⚠️ Only 41 segments available. Skipping noise filtering.
# Loading microVOSTN_R_10_CommonFiltered_lfs --> Region: VOSTN, Side: R, Electrode: 10 true region: VO
# ⚠️ Only 41 segments available. Skipping noise filtering.
# Loading microVIM_L_4_CommonFiltered_lfs --> Region: VIM, Side: L, Electrode: 4 true region: VIM
# ⚠️ Only 41 segments available. Skipping noise filtering.
# Loading microVIM_L_5_CommonFiltered_lfs --> Region: VIM, Side: L, Electrode: 5 true region: VIM
# ⚠️ Only 41 segments available. Skipping noise filtering.
# Loading microVIM_L_6_CommonFiltered_lfs --> Region: VIM, Side: L, Electrode: 6 true region: VIM
# ⚠️ Only 41 segments available. Skipping noise filtering.
# Loading microVIM_L_7_CommonFiltered_lfs --> Region: VIM, Side: L, Electrode: 7 true region: VIM
# ⚠️ Only 41 segments available. Skipping noise filtering.
# Loading microVIM_L_8_CommonFiltered_lfs --> Region: VIM, Side: L, Electrode: 8 true region: VIM
# ⚠️ Only 41 segments available. Skipping noise filtering.
# Loading microVIM_R_4_CommonFiltered_lfs --> Region: VIM, Side: R, Electrode: 4 true region: VIM
# ⚠️ Only 41 segments available. Skipping noise filtering.
# Loading microVIM_R_5_CommonFiltered_lfs --> Region: VIM, Side: R, Electrode: 5 true region: VIM
# ⚠️ Only 41 segments available. Skipping noise filtering.
# Loading microVIM_R_6_CommonFiltered_lfs --> Region: VIM, Side: R, Electrode: 6 true region: VIM
# ⚠️ Only 41 segments available. Skipping noise filtering.
# Loading microVIM_R_7_CommonFiltered_lfs --> Region: VIM, Side: R, Electrode: 7 true region: VIM
# ⚠️ Only 41 segments available. Skipping noise filtering.
# Loading microVIM_R_8_CommonFiltered_lfs --> Region: VIM, Side: R, Electrode: 8 true region: VIM
# ⚠️ Only 41 segments available. Skipping noise filtering.
# held out channels :  {'GPi': 20, 'STN': 12, 'VO': 8, 'VIM': 10}
# Loading data from subject: S20 period: p3
# Loading microGPi1_L_4_CommonFiltered_lfs --> Region: GPi1, Side: L, Electrode: 4 true region: GPi
# ⚠️ Only 62 segments available. Skipping noise filtering.
# Loading microGPi1_L_5_CommonFiltered_lfs --> Region: GPi1, Side: L, Electrode: 5 true region: GPi
# ⚠️ Only 62 segments available. Skipping noise filtering.
# Loading microGPi1_L_6_CommonFiltered_lfs --> Region: GPi1, Side: L, Electrode: 6 true region: GPi
# ⚠️ Only 62 segments available. Skipping noise filtering.
# Loading microGPi1_L_7_CommonFiltered_lfs --> Region: GPi1, Side: L, Electrode: 7 true region: GPi
# ⚠️ Only 62 segments available. Skipping noise filtering.
# Loading microGPi1_L_8_CommonFiltered_lfs --> Region: GPi1, Side: L, Electrode: 8 true region: GPi
# ⚠️ Only 62 segments available. Skipping noise filtering.
# Loading microGPi1_R_4_CommonFiltered_lfs --> Region: GPi1, Side: R, Electrode: 4 true region: GPi
# ⚠️ Only 62 segments available. Skipping noise filtering.
# Loading microGPi1_R_5_CommonFiltered_lfs --> Region: GPi1, Side: R, Electrode: 5 true region: GPi
# ⚠️ Only 62 segments available. Skipping noise filtering.
# Loading microGPi1_R_6_CommonFiltered_lfs --> Region: GPi1, Side: R, Electrode: 6 true region: GPi
# ⚠️ Only 62 segments available. Skipping noise filtering.
# Loading microGPi1_R_7_CommonFiltered_lfs --> Region: GPi1, Side: R, Electrode: 7 true region: GPi
# ⚠️ Only 62 segments available. Skipping noise filtering.
# Loading microGPi1_R_8_CommonFiltered_lfs --> Region: GPi1, Side: R, Electrode: 8 true region: GPi
# ⚠️ Only 62 segments available. Skipping noise filtering.
# Loading microGPi2_L_4_CommonFiltered_lfs --> Region: GPi2, Side: L, Electrode: 4 true region: GPi
# ⚠️ Only 62 segments available. Skipping noise filtering.
# Loading microGPi2_L_5_CommonFiltered_lfs --> Region: GPi2, Side: L, Electrode: 5 true region: GPi
# ⚠️ Only 62 segments available. Skipping noise filtering.
# Loading microGPi2_L_6_CommonFiltered_lfs --> Region: GPi2, Side: L, Electrode: 6 true region: GPi
# ⚠️ Only 62 segments available. Skipping noise filtering.
# Loading microGPi2_L_7_CommonFiltered_lfs --> Region: GPi2, Side: L, Electrode: 7 true region: GPi
# ⚠️ Only 62 segments available. Skipping noise filtering.
# Loading microGPi2_L_8_CommonFiltered_lfs --> Region: GPi2, Side: L, Electrode: 8 true region: GPi
# ⚠️ Only 62 segments available. Skipping noise filtering.
# Loading microGPi2_R_4_CommonFiltered_lfs --> Region: GPi2, Side: R, Electrode: 4 true region: GPi
# ⚠️ Only 62 segments available. Skipping noise filtering.
# Loading microGPi2_R_5_CommonFiltered_lfs --> Region: GPi2, Side: R, Electrode: 5 true region: GPi
# ⚠️ Only 62 segments available. Skipping noise filtering.
# Loading microGPi2_R_6_CommonFiltered_lfs --> Region: GPi2, Side: R, Electrode: 6 true region: GPi
# ⚠️ Only 62 segments available. Skipping noise filtering.
# Loading microGPi2_R_7_CommonFiltered_lfs --> Region: GPi2, Side: R, Electrode: 7 true region: GPi
# ⚠️ Only 62 segments available. Skipping noise filtering.
# Loading microGPi2_R_8_CommonFiltered_lfs --> Region: GPi2, Side: R, Electrode: 8 true region: GPi
# ⚠️ Only 62 segments available. Skipping noise filtering.
# Loading microVOSTN_L_1_CommonFiltered_lfs --> Region: VOSTN, Side: L, Electrode: 1 true region: STN
# ⚠️ Only 62 segments available. Skipping noise filtering.
# Loading microVOSTN_L_2_CommonFiltered_lfs --> Region: VOSTN, Side: L, Electrode: 2 true region: STN
# ⚠️ Only 62 segments available. Skipping noise filtering.
# Loading microVOSTN_L_3_CommonFiltered_lfs --> Region: VOSTN, Side: L, Electrode: 3 true region: STN
# ⚠️ Only 62 segments available. Skipping noise filtering.
# Loading microVOSTN_L_4_CommonFiltered_lfs --> Region: VOSTN, Side: L, Electrode: 4 true region: STN
# ⚠️ Only 62 segments available. Skipping noise filtering.
# Loading microVOSTN_L_5_CommonFiltered_lfs --> Region: VOSTN, Side: L, Electrode: 5 true region: STN
# ⚠️ Only 62 segments available. Skipping noise filtering.
# Loading microVOSTN_L_6_CommonFiltered_lfs --> Region: VOSTN, Side: L, Electrode: 6 true region: STN
# ⚠️ Only 62 segments available. Skipping noise filtering.
# Loading microVOSTN_L_7_CommonFiltered_lfs --> Region: VOSTN, Side: L, Electrode: 7 true region: VO
# ⚠️ Only 62 segments available. Skipping noise filtering.
# Loading microVOSTN_L_8_CommonFiltered_lfs --> Region: VOSTN, Side: L, Electrode: 8 true region: VO
# ⚠️ Only 62 segments available. Skipping noise filtering.
# Loading microVOSTN_L_9_CommonFiltered_lfs --> Region: VOSTN, Side: L, Electrode: 9 true region: VO
# ⚠️ Only 62 segments available. Skipping noise filtering.
# Loading microVOSTN_L_10_CommonFiltered_lfs --> Region: VOSTN, Side: L, Electrode: 10 true region: VO
# ⚠️ Only 62 segments available. Skipping noise filtering.
# Loading microVOSTN_R_1_CommonFiltered_lfs --> Region: VOSTN, Side: R, Electrode: 1 true region: STN
# ⚠️ Only 62 segments available. Skipping noise filtering.
# Loading microVOSTN_R_2_CommonFiltered_lfs --> Region: VOSTN, Side: R, Electrode: 2 true region: STN
# ⚠️ Only 62 segments available. Skipping noise filtering.
# Loading microVOSTN_R_3_CommonFiltered_lfs --> Region: VOSTN, Side: R, Electrode: 3 true region: STN
# ⚠️ Only 62 segments available. Skipping noise filtering.
# Loading microVOSTN_R_4_CommonFiltered_lfs --> Region: VOSTN, Side: R, Electrode: 4 true region: STN
# ⚠️ Only 62 segments available. Skipping noise filtering.
# Loading microVOSTN_R_5_CommonFiltered_lfs --> Region: VOSTN, Side: R, Electrode: 5 true region: STN
# ⚠️ Only 62 segments available. Skipping noise filtering.
# Loading microVOSTN_R_6_CommonFiltered_lfs --> Region: VOSTN, Side: R, Electrode: 6 true region: STN
# ⚠️ Only 62 segments available. Skipping noise filtering.
# Loading microVOSTN_R_7_CommonFiltered_lfs --> Region: VOSTN, Side: R, Electrode: 7 true region: VO
# ⚠️ Only 62 segments available. Skipping noise filtering.
# Loading microVOSTN_R_8_CommonFiltered_lfs --> Region: VOSTN, Side: R, Electrode: 8 true region: VO
# ⚠️ Only 62 segments available. Skipping noise filtering.
# Loading microVOSTN_R_9_CommonFiltered_lfs --> Region: VOSTN, Side: R, Electrode: 9 true region: VO
# ⚠️ Only 62 segments available. Skipping noise filtering.
# Loading microVOSTN_R_10_CommonFiltered_lfs --> Region: VOSTN, Side: R, Electrode: 10 true region: VO
# ⚠️ Only 62 segments available. Skipping noise filtering.
# Loading microVIM_L_4_CommonFiltered_lfs --> Region: VIM, Side: L, Electrode: 4 true region: VIM
# ⚠️ Only 62 segments available. Skipping noise filtering.
# Loading microVIM_L_5_CommonFiltered_lfs --> Region: VIM, Side: L, Electrode: 5 true region: VIM
# ⚠️ Only 62 segments available. Skipping noise filtering.
# Loading microVIM_L_6_CommonFiltered_lfs --> Region: VIM, Side: L, Electrode: 6 true region: VIM
# ⚠️ Only 62 segments available. Skipping noise filtering.
# Loading microVIM_L_7_CommonFiltered_lfs --> Region: VIM, Side: L, Electrode: 7 true region: VIM
# ⚠️ Only 62 segments available. Skipping noise filtering.
# Loading microVIM_L_8_CommonFiltered_lfs --> Region: VIM, Side: L, Electrode: 8 true region: VIM
# ⚠️ Only 62 segments available. Skipping noise filtering.
# Loading microVIM_R_4_CommonFiltered_lfs --> Region: VIM, Side: R, Electrode: 4 true region: VIM
# ⚠️ Only 62 segments available. Skipping noise filtering.
# Loading microVIM_R_5_CommonFiltered_lfs --> Region: VIM, Side: R, Electrode: 5 true region: VIM
# ⚠️ Only 62 segments available. Skipping noise filtering.
# Loading microVIM_R_6_CommonFiltered_lfs --> Region: VIM, Side: R, Electrode: 6 true region: VIM
# ⚠️ Only 62 segments available. Skipping noise filtering.
# Loading microVIM_R_7_CommonFiltered_lfs --> Region: VIM, Side: R, Electrode: 7 true region: VIM
# ⚠️ Only 62 segments available. Skipping noise filtering.
# Loading microVIM_R_8_CommonFiltered_lfs --> Region: VIM, Side: R, Electrode: 8 true region: VIM
# ⚠️ Only 62 segments available. Skipping noise filtering.
# held out channels :  {'GPi': 20, 'STN': 12, 'VO': 8, 'VIM': 10}
# Shuffle segments...
# Generating training and validation pairs...
# Created 999978 total pairs (499989 similar, 499989 dissimilar) from 7 regions.
# Created 19992 total pairs (9996 similar, 9996 dissimilar) from 7 regions.
# Train set: 999978 pairs
# Validation set: 19992 pairs
# Batch size: 1024
# ===== Training Input Shape Info =====
# Train input shapes: x1: torch.Size([1024, 1, 10000]), x2: torch.Size([1024, 1, 10000])
# ===== Validation Input Shape Info =====
# Validation input shapes: x1: torch.Size([1024, 1, 10000]), x2: torch.Size([1024, 1, 10000])
#
#
# Training model...
# ===== Sample Forward Pass Shape Info =====
#
# Model Summary:
#
# SiameseNetMultiSubject(
#   (encoder): CNNEncoderMultiSubject(
#     (layers): ModuleList(
#       (0): Conv1d(1, 64, kernel_size=(15,), stride=(4,))
#       (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): GELU(approximate='none')
#       (3): MaxPool1d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (4): Dropout(p=0.3, inplace=False)
#       (5): Conv1d(64, 128, kernel_size=(11,), stride=(2,))
#       (6): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (7): GELU(approximate='none')
#       (8): MaxPool1d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (9): Dropout(p=0.3, inplace=False)
#       (10): Conv1d(128, 128, kernel_size=(11,), stride=(2,))
#       (11): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (12): GELU(approximate='none')
#       (13): MaxPool1d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (14): Dropout(p=0.3, inplace=False)
#       (15): Conv1d(128, 128, kernel_size=(11,), stride=(2,))
#       (16): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (17): GELU(approximate='none')
#       (18): MaxPool1d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (19): Dropout(p=0.3, inplace=False)
#       (20): Conv1d(128, 128, kernel_size=(7,), stride=(2,))
#       (21): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (22): GELU(approximate='none')
#       (23): Dropout(p=0.3, inplace=False)
#       (24): Conv1d(128, 128, kernel_size=(5,), stride=(2,))
#       (25): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (26): GELU(approximate='none')
#       (27): Dropout(p=0.3, inplace=False)
#       (28): AdaptiveAvgPool1d(output_size=10)
#     )
#     (fc): Sequential(
#       (0): Linear(in_features=1280, out_features=32, bias=True)
#       (1): Dropout(p=0.3, inplace=False)
#       (2): Linear(in_features=32, out_features=32, bias=True)
#     )
#   )
# )
# Total trainable parameters: 692,288
#
# Trainable parameters by layer:
# encoder.layers.0.weight                            960
# encoder.layers.0.bias                              64
# encoder.layers.1.weight                            64
# encoder.layers.1.bias                              64
# encoder.layers.5.weight                            90,112
# encoder.layers.5.bias                              128
# encoder.layers.6.weight                            128
# encoder.layers.6.bias                              128
# encoder.layers.10.weight                           180,224
# encoder.layers.10.bias                             128
# encoder.layers.11.weight                           128
# encoder.layers.11.bias                             128
# encoder.layers.15.weight                           180,224
# encoder.layers.15.bias                             128
# encoder.layers.16.weight                           128
# encoder.layers.16.bias                             128
# encoder.layers.20.weight                           114,688
# encoder.layers.20.bias                             128
# encoder.layers.21.weight                           128
# encoder.layers.21.bias                             128
# encoder.layers.24.weight                           81,920
# encoder.layers.24.bias                             128
# encoder.layers.25.weight                           128
# encoder.layers.25.bias                             128
# encoder.fc.0.weight                                40,960
# encoder.fc.0.bias                                  32
# encoder.fc.2.weight                                1,024
# encoder.fc.2.bias                                  32
# Epoch 1 Train Accuracy: 0.5010
# Epoch 1 Test Accuracy: 0.5000
# Epoch 1/1 - LR: 0.0100000000 - Train Loss: 0.0657 - Test Loss: 0.0994
#  New best model saved at epoch 1
# Extracting embeddings...
# Extracting embeddings...
# STN: 13930 segments
# VO: 10404 segments
# GPi: 31425 segments
# VIM: 6728 segments
# VA: 8207 segments
# PPN: 9129 segments
# SNR: 3827 segments
# Computing clustering metrics...
# Generating and saving confusion matrices...
# ✅ Confusion matrix saved to: data\multi_subject_training\PSC_model\cm_val.png
# ✅ Confusion matrix saved to: data\multi_subject_training\PSC_model\cm_test.png
# ✅ Confusion matrix saved to: data\multi_subject_training\PSC_model\cm_heldout.png
# ✅ Evaluation saved to results\multi_subject\evaluation_summary_multi_subject.xlsx

# %% [markdown]
# # Training functional encoder on aggregated dataset including several subjects and sessions Using MSC method
# This sections creates a new dataset and adds all recording sessions and trains and evaluates a functional encoder on that dataset, using held out times (test dataset) and held out channels for evaluation.

# %%
# Check GPU
device = get_device()
print(f" Using {device}")

# ----------- Config ------------ 
# training parameters
EPOCHS = 200
DATASET_SIZE = 1000000
LEARNING_RATE = 1e-3
BATCH_SIZE = 128
TEMPERATURE = 0.2

# model parameters
EMBEDDING_DIM = 32
PROJ_DIM = 32
VERSION = "v1(MSC)"
DROPOUT = 0.35
RANDOM_SEED=42


# data preparation 
SEGMENT_LENGTH = 10000 # in ms here is 10 seconds

# visualization
show_model = True
#--------------------------------


dataPath = "D:\\transfer\\micro voluntary dataset\\lfs data" # path to data folder (replace with your own data path)
experiment = "Multi session training" 
subject_counter = 0

training_segments_dict = {}
validation_segments_dict = {}
testing_segments_dict = {}
held_out_channels_dict = {}

for isubject in subject_sessions.keys():
    subject_counter += 1
    for iperiod in subject_sessions[isubject]:
        print("Loading data from subject: S" + str(subject_counter) + " period: " + iperiod)
        # load microelectrode labels which contains the names of all microelectrodes in this session
        micro_electrode_path = dataPath  + os.sep + isubject + os.sep + iperiod + os.sep
        try:
            microelectrodes = load_micro_labels(micro_electrode_path + "microLabels.mat")
        except:
            mat_contents = loadmat(micro_electrode_path + "microLabels.mat")
            micro_labels = mat_contents['microLabels'] 
            microelectrodes = [str(label[0]) if isinstance(label, np.ndarray) else str(label) for label in micro_labels.squeeze()]

        
        region_electrode_count = {}
        hold_out_check = 4 # holds 1 channel out every n channels

        # Parse and print them
        for microelectrode in microelectrodes:
            region, side, electrode = parse_label(microelectrode)

            # get true region of this electrode
            true_region = get_true_region(isubject, region, side, electrode)
            if true_region != 'unknown':
                print(f"Loading {microelectrode} --> Region: {region}, Side: {side}, Electrode: {electrode} true region: {true_region}")

                # load data
                mat_path = os.path.join(micro_electrode_path, microelectrode + ".mat")
                raw_signal = None 
                try:
                    # First try HDF5 (MATLAB v7.3 format)
                    with h5py.File(mat_path, "r") as f:
                        raw_signal = np.array(f["data"]).squeeze()
                        fs = int(np.array(f["fs"]).squeeze())
                except FileNotFoundError:
                    print(f"⚠️ File not found: {mat_path}. Skipping electrode.")
                    continue  # Skip to next electrode
                except (OSError, KeyError):
                    # Fall back to standard .mat format (pre-v7.3)
                    try:
                        mat = scipy.io.loadmat(mat_path)
                        raw_signal = np.array(mat["data"]).squeeze()
                        fs = int(np.array(mat["fs"]).squeeze())
                    except Exception as e:
                        print(f"⚠️ Failed to load (not a valid .mat file): {mat_path}. Error: {e}")
                        continue  # Skip if even fallback fails

                # Remove big 60Hz artifacts
                filtered_signal = notch_filter(raw_signal,fs)

                # Normalize session recording
                normalized_signal = normalize_signal(filtered_signal)

                # Apply notch filters at 60Hz and its harmonics
                normalized_signal = notch_filter(normalized_signal,fs,freq=60)
                normalized_signal = notch_filter(normalized_signal,fs,freq=120)
                normalized_signal = notch_filter(normalized_signal,fs,freq=180)

                # Segment data into windows
                signal_segments = segment_data(normalized_signal, SEGMENT_LENGTH)

                # Skip sessions with too few segments
                if len(signal_segments) < 10:
                    print("session too short")
                    continue

                # Check if this region already has 3 electrodes, add this channel to held out channels
                region_electrode_count[true_region] = region_electrode_count.get(true_region ,0) + 1
                if region_electrode_count[true_region] % hold_out_check ==0:
                    # add to held out channel dictionary
                    if true_region in held_out_channels_dict:
                        held_out_channels_dict[true_region] = np.concat([held_out_channels_dict[true_region], signal_segments])
                    else:
                        held_out_channels_dict[true_region] = signal_segments
                else: 
                    # Split segments into training, validation, and testing sets
                    num_val = int(0.15 * len(signal_segments))
                    num_test = int(0.15 * len(signal_segments))
                    val_segments = signal_segments[:num_val]
                    test_segments = signal_segments[num_val:num_val+num_test]
                    train_segments = signal_segments[num_val+num_test:]

                    # add to training dictionary
                    if true_region in training_segments_dict:
                        training_segments_dict[true_region] = np.concat([training_segments_dict[true_region], train_segments])
                    else:
                        training_segments_dict[true_region] = train_segments

                    # add to validation dictionary
                    if true_region in validation_segments_dict:
                        validation_segments_dict[true_region] = np.concat([validation_segments_dict[true_region], val_segments])
                    else:
                        validation_segments_dict[true_region] = val_segments

                    # add to testing dictionary
                    if true_region in testing_segments_dict:
                        testing_segments_dict[true_region] = np.concat([testing_segments_dict[true_region], test_segments])
                    else:
                        testing_segments_dict[true_region] = test_segments

        # print held out channels
        print("held out channels : ", region_electrode_count)


# Shuffle segments within each region key before training
print("Shuffle segments...")
for d in [training_segments_dict, validation_segments_dict, testing_segments_dict, held_out_channels_dict]:
    for k in d:
        np.random.shuffle(d[k])

# save datasets
save_path = os.path.join("data","multi_subject_training","data_splits")
os.makedirs(save_path, exist_ok=True)
with open(os.path.join(save_path, "training_segments.pkl"), "wb") as f:
    pickle.dump(training_segments_dict, f)
with open(os.path.join(save_path, "validation_segments.pkl"), "wb") as f:
    pickle.dump(validation_segments_dict, f)
with open(os.path.join(save_path, "testing_segments.pkl"), "wb") as f:
    pickle.dump(testing_segments_dict, f)
with open(os.path.join(save_path, "heldout_channels.pkl"), "wb") as f:
    pickle.dump(held_out_channels_dict, f)


# Generate training and validation pairs for the Pairwise Siamese Contrastive (PSC) method
print("Generating training and validation datasets...")
train_supcon_ds = SupConDataset(training_segments_dict, transform=zscore_transform)
val_supcon_ds   = SupConDataset(validation_segments_dict, transform=zscore_transform)

train_supcon_loader = DataLoader(train_supcon_ds, batch_size=BATCH_SIZE, shuffle=True, drop_last=True)
val_supcon_loader   = DataLoader(val_supcon_ds,   batch_size=BATCH_SIZE, shuffle=True, drop_last=True)
print(f"Train set: {len(train_supcon_ds)} pairs")
print(f"Validation set: {len(val_supcon_ds)} pairs")
print(f"Batch size: {BATCH_SIZE}")

# --- keep  pair dataset for validation after each epoch to compare with PSC ---
val_pairs, val_labels = create_balanced_pairs(validation_segments_dict, max_dataset_size=min(20000, len(val_supcon_ds)*2))
val_pair_ds = LFPDataset(val_pairs, val_labels)
val_pair_loader = DataLoader(val_pair_ds, batch_size=BATCH_SIZE)


# Model setup
print("Training model...")
model = SupConNetMultiSubject(embedding_dim=EMBEDDING_DIM, proj_dim=PROJ_DIM, dropout=DROPOUT).to(device)
if show_model:
    print_model_summary(model, train_supcon_loader, device)
    show_model = False

save_path = os.path.join("results","multi_subject","MSC_model")
os.makedirs(save_path, exist_ok=True)
trained_model = training_validate_loop_supcon(
model, train_supcon_loader, val_pair_loader, device, save_path,
epochs=EPOCHS, lr=LEARNING_RATE,             # lower LR
temperature=TEMPERATURE,                    # a bit larger temp often helps early
add_nn=True                        # disable NN positives on single-subject
)


# Extract encoder and evaluate
trained_model.eval()
encoder_model = trained_model.encoder
encoder_model.eval()

# Extract embeddings
print("Extracting embeddings...")
train_emb, train_labels_text = embed_segments_dict(training_segments_dict, encoder_model, device)
val_emb, val_labels_text = embed_segments_dict(validation_segments_dict, encoder_model, device)
test_emb, test_labels_text = embed_segments_dict(testing_segments_dict, encoder_model, device)
held_emb, held_labels_text = embed_segments_dict(held_out_channels_dict, encoder_model, device)

# KNN Evaluation
print("Extracting embeddings...")
for k in training_segments_dict:
    print(f"{k}: {len(training_segments_dict[k])} segments")

# make region balanced reference set for knn
ref_emb, ref_labels = make_balanced_reference(train_emb, train_labels_text, per_class=None, seed=42)
results_train = evaluate_knn(ref_emb, ref_labels, train_emb, train_labels_text)
results_val = evaluate_knn(ref_emb, ref_labels, val_emb, val_labels_text)
results_test = evaluate_knn(ref_emb, ref_labels, test_emb, test_labels_text)
results_held = evaluate_knn(ref_emb, ref_labels, held_emb, held_labels_text)

# Chance & clustering
print ("Computing clustering metrics...")
chance_train = compute_chance_levels(train_labels_text)
chance_val = compute_chance_levels(val_labels_text)
chance_test = compute_chance_levels(test_labels_text)    
chance_held = compute_chance_levels(held_labels_text)

metrics_train = evaluate_clustering_metrics(train_emb, train_labels_text)
metrics_val = evaluate_clustering_metrics(val_emb, val_labels_text)
metrics_test = evaluate_clustering_metrics(test_emb, test_labels_text)
metrics_held = evaluate_clustering_metrics(held_emb, held_labels_text)

# Save confusion matrix 
print("Generating and saving confusion matrices...")
plot_and_save_confusion_matrix(val_labels_text, results_val['predictions'], sorted(set(val_labels_text)), "Validation Confusion", os.path.join(save_path, "cm_val.png"))
plot_and_save_confusion_matrix(test_labels_text, results_test['predictions'], sorted(set(test_labels_text)), "Test Confusion", os.path.join(save_path, "cm_test.png"))
plot_and_save_confusion_matrix(held_labels_text, results_held['predictions'], sorted(set(held_labels_text)), "Held-Out channel Confusion", os.path.join(save_path, "cm_heldout.png"))

# Embedding visualization
test_region_list = [label for label in test_labels_text]
test_side_list = ["" for _ in test_labels_text]
test_electrode_list = [""] * len(test_labels_text)
fig,_ = plot_interactive_embeddings(test_emb, test_region_list, test_electrode_list, test_side_list, dim=2, method='pca', metric='euclidean', show_ellipses=True, verbose=False)
pio.write_image(fig, os.path.join(save_path, f"embedding_testset_pca_2D.png"), format="png", width=950, height=700)
pio.write_json(fig,  os.path.join(save_path, f"embedding_testset_pca_2D.json"), pretty=True)

fig,_ = plot_interactive_embeddings(test_emb, test_region_list, test_electrode_list, test_side_list, dim=3, method='pca', metric='euclidean', show_ellipses=True, verbose=False)
pio.write_image(fig, os.path.join(save_path, f"embedding_testset_pca_3D.png"), format="png", width=950, height=700)
pio.write_json(fig,  os.path.join(save_path, f"embedding_testset_pca_3D.json"), pretty=True)
has_heldout = any(len(v) > 0 for v in held_out_channels_dict.values())

held_out_region_list = [label for label in held_labels_text]
held_out_side_list = ["" for _ in held_labels_text]
held_out_electrode_list = [""] * len(held_labels_text)
fig,_ = plot_interactive_embeddings(held_emb, held_out_region_list, held_out_electrode_list, held_out_side_list, dim=3, method='pca', metric='euclidean', show_ellipses=True, verbose=False)
pio.write_image(fig, os.path.join(save_path, f"embedding_heldout_pca_3D.png"), format="png", width=950, height=700)
pio.write_json(fig,  os.path.join(save_path, f"embedding_heldout_pca_3D.json"), pretty=True)


# Save results
save_evaluation_to_excel(
    subject_id="Multi-subject training",
    model_name=VERSION,
    results_train=results_train,
    results_test=results_test,
    results_heldout=results_held,
    clustering_train=metrics_train,
    clustering_test=metrics_test,
    clustering_heldout=metrics_held,
    chance_train=chance_train,
    chance_test=chance_test,
    chance_heldout=chance_held,
    save_path=os.path.join("results","multi_subject" , "evaluation_summary_multi_subject.xlsx")
)
# Out:
#  Using cuda
# Loading data from subject: S1 period: p7
# Loading microSTN_L_1_CommonFiltered_lfs --> Region: STN, Side: L, Electrode: 1 true region: STN
# Segments before cleaning: 144 | After cleaning: 118
# Loading microSTN_L_2_CommonFiltered_lfs --> Region: STN, Side: L, Electrode: 2 true region: STN
# Segments before cleaning: 144 | After cleaning: 141
# Loading microSTN_L_3_CommonFiltered_lfs --> Region: STN, Side: L, Electrode: 3 true region: STN
# Segments before cleaning: 144 | After cleaning: 78
# Loading microVoaVop_L_1_CommonFiltered_lfs --> Region: VoaVop, Side: L, Electrode: 1 true region: VO
# Segments before cleaning: 144 | After cleaning: 78
# Loading microVoaVop_L_2_CommonFiltered_lfs --> Region: VoaVop, Side: L, Electrode: 2 true region: VO
# Segments before cleaning: 144 | After cleaning: 81
# Loading microVoaVop_L_3_CommonFiltered_lfs --> Region: VoaVop, Side: L, Electrode: 3 true region: VO
# Segments before cleaning: 144 | After cleaning: 113
# Loading microSTN_R_1_CommonFiltered_lfs --> Region: STN, Side: R, Electrode: 1 true region: STN
# Segments before cleaning: 144 | After cleaning: 66
# Loading microSTN_R_2_CommonFiltered_lfs --> Region: STN, Side: R, Electrode: 2 true region: STN
# Segments before cleaning: 144 | After cleaning: 82
# Loading microSTN_R_3_CommonFiltered_lfs --> Region: STN, Side: R, Electrode: 3 true region: STN
# Segments before cleaning: 144 | After cleaning: 142
# Loading microVoaVop_R_1_CommonFiltered_lfs --> Region: VoaVop, Side: R, Electrode: 1 true region: VO
# Segments before cleaning: 144 | After cleaning: 118
# Loading microVoaVop_R_2_CommonFiltered_lfs --> Region: VoaVop, Side: R, Electrode: 2 true region: VO
# Segments before cleaning: 144 | After cleaning: 130
# Loading microVoaVop_R_3_CommonFiltered_lfs --> Region: VoaVop, Side: R, Electrode: 3 true region: VO
# Segments before cleaning: 144 | After cleaning: 124
# Loading microGPi1_L_1_CommonFiltered_lfs --> Region: GPi1, Side: L, Electrode: 1 true region: GPi
# Segments before cleaning: 144 | After cleaning: 126
# Loading microGPi1_L_2_CommonFiltered_lfs --> Region: GPi1, Side: L, Electrode: 2 true region: GPi
# Segments before cleaning: 144 | After cleaning: 143
# Loading microGPi1_L_3_CommonFiltered_lfs --> Region: GPi1, Side: L, Electrode: 3 true region: GPi
# Segments before cleaning: 144 | After cleaning: 144
# Loading microGPi1_L_4_CommonFiltered_lfs --> Region: GPi1, Side: L, Electrode: 4 true region: GPi
# Segments before cleaning: 144 | After cleaning: 138
# Loading microGPi1_L_5_CommonFiltered_lfs --> Region: GPi1, Side: L, Electrode: 5 true region: GPi
# Segments before cleaning: 144 | After cleaning: 120
# Loading microGPi1_L_6_CommonFiltered_lfs --> Region: GPi1, Side: L, Electrode: 6 true region: GPi
# Segments before cleaning: 144 | After cleaning: 96
# Loading microGPi1_R_4_CommonFiltered_lfs --> Region: GPi1, Side: R, Electrode: 4 true region: GPi
# Segments before cleaning: 144 | After cleaning: 69
# Loading microGPi1_R_5_CommonFiltered_lfs --> Region: GPi1, Side: R, Electrode: 5 true region: GPi
# Segments before cleaning: 144 | After cleaning: 99
# Loading microGPi1_R_6_CommonFiltered_lfs --> Region: GPi1, Side: R, Electrode: 6 true region: GPi
# Segments before cleaning: 144 | After cleaning: 93
# Loading microGPi1_R_7_CommonFiltered_lfs --> Region: GPi1, Side: R, Electrode: 7 true region: GPi
# Segments before cleaning: 144 | After cleaning: 75
# Loading microGPi1_R_8_CommonFiltered_lfs --> Region: GPi1, Side: R, Electrode: 8 true region: GPi
# Segments before cleaning: 144 | After cleaning: 101
# Loading microGPi2_L_4_CommonFiltered_lfs --> Region: GPi2, Side: L, Electrode: 4 true region: GPi
# Segments before cleaning: 144 | After cleaning: 96
# Loading microGPi2_L_5_CommonFiltered_lfs --> Region: GPi2, Side: L, Electrode: 5 true region: GPi
# Segments before cleaning: 144 | After cleaning: 132
# Loading microGPi2_L_6_CommonFiltered_lfs --> Region: GPi2, Side: L, Electrode: 6 true region: GPi
# Segments before cleaning: 144 | After cleaning: 131
# Loading microGPi2_R_4_CommonFiltered_lfs --> Region: GPi2, Side: R, Electrode: 4 true region: GPi
# Segments before cleaning: 144 | After cleaning: 108
# Loading microGPi2_R_5_CommonFiltered_lfs --> Region: GPi2, Side: R, Electrode: 5 true region: GPi
# Segments before cleaning: 144 | After cleaning: 113
# Loading microGPi2_R_6_CommonFiltered_lfs --> Region: GPi2, Side: R, Electrode: 6 true region: GPi
# Segments before cleaning: 144 | After cleaning: 112
# Loading microGPi2_R_7_CommonFiltered_lfs --> Region: GPi2, Side: R, Electrode: 7 true region: GPi
# Segments before cleaning: 144 | After cleaning: 108
# Loading microGPi2_R_8_CommonFiltered_lfs --> Region: GPi2, Side: R, Electrode: 8 true region: GPi
# Segments before cleaning: 144 | After cleaning: 90
# Loading microVIM_L_1_CommonFiltered_lfs --> Region: VIM, Side: L, Electrode: 1 true region: VIM
# Segments before cleaning: 144 | After cleaning: 68
# Loading microVIM_L_2_CommonFiltered_lfs --> Region: VIM, Side: L, Electrode: 2 true region: VIM
# Segments before cleaning: 144 | After cleaning: 56
# Loading microVIM_L_3_CommonFiltered_lfs --> Region: VIM, Side: L, Electrode: 3 true region: VIM
# Segments before cleaning: 144 | After cleaning: 60
# Loading microVIM_L_4_CommonFiltered_lfs --> Region: VIM, Side: L, Electrode: 4 true region: VIM
# Segments before cleaning: 144 | After cleaning: 83
# Loading microVIM_L_5_CommonFiltered_lfs --> Region: VIM, Side: L, Electrode: 5 true region: VIM
# Segments before cleaning: 144 | After cleaning: 113
# Loading microVIM_L_6_CommonFiltered_lfs --> Region: VIM, Side: L, Electrode: 6 true region: VIM
# Segments before cleaning: 144 | After cleaning: 87
# Loading microVIM_R_4_CommonFiltered_lfs --> Region: VIM, Side: R, Electrode: 4 true region: VIM
# Segments before cleaning: 144 | After cleaning: 138
# Loading microVIM_R_5_CommonFiltered_lfs --> Region: VIM, Side: R, Electrode: 5 true region: VIM
# Segments before cleaning: 144 | After cleaning: 141
# Loading microVIM_R_6_CommonFiltered_lfs --> Region: VIM, Side: R, Electrode: 6 true region: VIM
# Segments before cleaning: 144 | After cleaning: 143
# held out channels :  {'STN': 6, 'VO': 6, 'GPi': 19, 'VIM': 9}
# Loading data from subject: S1 period: p8
# Loading microSTN_L_1_CommonFiltered_lfs --> Region: STN, Side: L, Electrode: 1 true region: STN
# Segments before cleaning: 430 | After cleaning: 340
# Loading microSTN_L_2_CommonFiltered_lfs --> Region: STN, Side: L, Electrode: 2 true region: STN
# Segments before cleaning: 430 | After cleaning: 419
# Loading microSTN_L_3_CommonFiltered_lfs --> Region: STN, Side: L, Electrode: 3 true region: STN
# Segments before cleaning: 430 | After cleaning: 134
# Loading microVoaVop_L_1_CommonFiltered_lfs --> Region: VoaVop, Side: L, Electrode: 1 true region: VO
# Segments before cleaning: 430 | After cleaning: 172
# Loading microVoaVop_L_2_CommonFiltered_lfs --> Region: VoaVop, Side: L, Electrode: 2 true region: VO
# Segments before cleaning: 430 | After cleaning: 212
# Loading microVoaVop_L_3_CommonFiltered_lfs --> Region: VoaVop, Side: L, Electrode: 3 true region: VO
# Segments before cleaning: 430 | After cleaning: 332
# Loading microSTN_R_1_CommonFiltered_lfs --> Region: STN, Side: R, Electrode: 1 true region: STN
# Segments before cleaning: 430 | After cleaning: 167
# Loading microSTN_R_2_CommonFiltered_lfs --> Region: STN, Side: R, Electrode: 2 true region: STN
# Segments before cleaning: 430 | After cleaning: 205
# Loading microSTN_R_3_CommonFiltered_lfs --> Region: STN, Side: R, Electrode: 3 true region: STN
# Segments before cleaning: 430 | After cleaning: 383
# Loading microVoaVop_R_1_CommonFiltered_lfs --> Region: VoaVop, Side: R, Electrode: 1 true region: VO
# Segments before cleaning: 430 | After cleaning: 221
# Loading microVoaVop_R_2_CommonFiltered_lfs --> Region: VoaVop, Side: R, Electrode: 2 true region: VO
# Segments before cleaning: 430 | After cleaning: 283
# Loading microVoaVop_R_3_CommonFiltered_lfs --> Region: VoaVop, Side: R, Electrode: 3 true region: VO
# Segments before cleaning: 430 | After cleaning: 230
# Loading microGPi1_L_1_CommonFiltered_lfs --> Region: GPi1, Side: L, Electrode: 1 true region: GPi
# Segments before cleaning: 430 | After cleaning: 327
# Loading microGPi1_L_2_CommonFiltered_lfs --> Region: GPi1, Side: L, Electrode: 2 true region: GPi
# Segments before cleaning: 430 | After cleaning: 398
# Loading microGPi1_L_3_CommonFiltered_lfs --> Region: GPi1, Side: L, Electrode: 3 true region: GPi
# Segments before cleaning: 430 | After cleaning: 421
# Loading microGPi1_L_4_CommonFiltered_lfs --> Region: GPi1, Side: L, Electrode: 4 true region: GPi
# Segments before cleaning: 430 | After cleaning: 371
# Loading microGPi1_L_5_CommonFiltered_lfs --> Region: GPi1, Side: L, Electrode: 5 true region: GPi
# Segments before cleaning: 430 | After cleaning: 316
# Loading microGPi1_L_6_CommonFiltered_lfs --> Region: GPi1, Side: L, Electrode: 6 true region: GPi
# Segments before cleaning: 430 | After cleaning: 246
# Loading microGPi1_R_4_CommonFiltered_lfs --> Region: GPi1, Side: R, Electrode: 4 true region: GPi
# Segments before cleaning: 430 | After cleaning: 195
# Loading microGPi1_R_5_CommonFiltered_lfs --> Region: GPi1, Side: R, Electrode: 5 true region: GPi
# Segments before cleaning: 430 | After cleaning: 282
# Loading microGPi1_R_6_CommonFiltered_lfs --> Region: GPi1, Side: R, Electrode: 6 true region: GPi
# Segments before cleaning: 430 | After cleaning: 296
# Loading microGPi1_R_7_CommonFiltered_lfs --> Region: GPi1, Side: R, Electrode: 7 true region: GPi
# Segments before cleaning: 430 | After cleaning: 212
# Loading microGPi1_R_8_CommonFiltered_lfs --> Region: GPi1, Side: R, Electrode: 8 true region: GPi
# Segments before cleaning: 430 | After cleaning: 265
# Loading microGPi2_L_4_CommonFiltered_lfs --> Region: GPi2, Side: L, Electrode: 4 true region: GPi
# Segments before cleaning: 430 | After cleaning: 256
# Loading microGPi2_L_5_CommonFiltered_lfs --> Region: GPi2, Side: L, Electrode: 5 true region: GPi
# Segments before cleaning: 430 | After cleaning: 376
# Loading microGPi2_L_6_CommonFiltered_lfs --> Region: GPi2, Side: L, Electrode: 6 true region: GPi
# Segments before cleaning: 430 | After cleaning: 348
# Loading microGPi2_R_4_CommonFiltered_lfs --> Region: GPi2, Side: R, Electrode: 4 true region: GPi
# Segments before cleaning: 430 | After cleaning: 276
# Loading microGPi2_R_5_CommonFiltered_lfs --> Region: GPi2, Side: R, Electrode: 5 true region: GPi
# Segments before cleaning: 430 | After cleaning: 247
# Loading microGPi2_R_6_CommonFiltered_lfs --> Region: GPi2, Side: R, Electrode: 6 true region: GPi
# Segments before cleaning: 430 | After cleaning: 299
# Loading microGPi2_R_7_CommonFiltered_lfs --> Region: GPi2, Side: R, Electrode: 7 true region: GPi
# Segments before cleaning: 430 | After cleaning: 325
# Loading microGPi2_R_8_CommonFiltered_lfs --> Region: GPi2, Side: R, Electrode: 8 true region: GPi
# Segments before cleaning: 430 | After cleaning: 273
# Loading microVIM_L_1_CommonFiltered_lfs --> Region: VIM, Side: L, Electrode: 1 true region: VIM
# Segments before cleaning: 430 | After cleaning: 134
# Loading microVIM_L_2_CommonFiltered_lfs --> Region: VIM, Side: L, Electrode: 2 true region: VIM
# Segments before cleaning: 430 | After cleaning: 167
# Loading microVIM_L_3_CommonFiltered_lfs --> Region: VIM, Side: L, Electrode: 3 true region: VIM
# Segments before cleaning: 430 | After cleaning: 161
# Loading microVIM_L_4_CommonFiltered_lfs --> Region: VIM, Side: L, Electrode: 4 true region: VIM
# Segments before cleaning: 430 | After cleaning: 232
# Loading microVIM_L_5_CommonFiltered_lfs --> Region: VIM, Side: L, Electrode: 5 true region: VIM
# Segments before cleaning: 430 | After cleaning: 346
# Loading microVIM_L_6_CommonFiltered_lfs --> Region: VIM, Side: L, Electrode: 6 true region: VIM
# Segments before cleaning: 430 | After cleaning: 274
# Loading microVIM_R_4_CommonFiltered_lfs --> Region: VIM, Side: R, Electrode: 4 true region: VIM
# Segments before cleaning: 430 | After cleaning: 385
# Loading microVIM_R_5_CommonFiltered_lfs --> Region: VIM, Side: R, Electrode: 5 true region: VIM
# Segments before cleaning: 430 | After cleaning: 383
# Loading microVIM_R_6_CommonFiltered_lfs --> Region: VIM, Side: R, Electrode: 6 true region: VIM
# Segments before cleaning: 430 | After cleaning: 416
# held out channels :  {'STN': 6, 'VO': 6, 'GPi': 19, 'VIM': 9}
# Loading data from subject: S2 period: p2
# Loading microGPi1_L_4_CommonFiltered_lfs --> Region: GPi1, Side: L, Electrode: 4 true region: GPi
# ⚠️ Only 13 segments available. Skipping noise filtering.
# Loading microGPi1_L_5_CommonFiltered_lfs --> Region: GPi1, Side: L, Electrode: 5 true region: GPi
# ⚠️ Only 13 segments available. Skipping noise filtering.
# Loading microGPi1_L_6_CommonFiltered_lfs --> Region: GPi1, Side: L, Electrode: 6 true region: GPi
# ⚠️ Only 13 segments available. Skipping noise filtering.
# Loading microGPi1_R_4_CommonFiltered_lfs --> Region: GPi1, Side: R, Electrode: 4 true region: GPi
# ⚠️ Only 13 segments available. Skipping noise filtering.
# Loading microGPi1_R_5_CommonFiltered_lfs --> Region: GPi1, Side: R, Electrode: 5 true region: GPi
# ⚠️ Only 13 segments available. Skipping noise filtering.
# Loading microGPi1_R_6_CommonFiltered_lfs --> Region: GPi1, Side: R, Electrode: 6 true region: GPi
# ⚠️ Only 13 segments available. Skipping noise filtering.
# Loading microGPi2_L_4_CommonFiltered_lfs --> Region: GPi2, Side: L, Electrode: 4 true region: GPi
# ⚠️ Only 13 segments available. Skipping noise filtering.
# Loading microGPi2_L_5_CommonFiltered_lfs --> Region: GPi2, Side: L, Electrode: 5 true region: GPi
# ⚠️ Only 13 segments available. Skipping noise filtering.
# Loading microGPi2_L_6_CommonFiltered_lfs --> Region: GPi2, Side: L, Electrode: 6 true region: GPi
# ⚠️ Only 13 segments available. Skipping noise filtering.
# Loading microGPi2_R_4_CommonFiltered_lfs --> Region: GPi2, Side: R, Electrode: 4 true region: GPi
# ⚠️ Only 13 segments available. Skipping noise filtering.
# Loading microGPi2_R_5_CommonFiltered_lfs --> Region: GPi2, Side: R, Electrode: 5 true region: GPi
# ⚠️ Only 13 segments available. Skipping noise filtering.
# Loading microGPi2_R_6_CommonFiltered_lfs --> Region: GPi2, Side: R, Electrode: 6 true region: GPi
# ⚠️ Only 13 segments available. Skipping noise filtering.
# Loading microVA_L_4_CommonFiltered_lfs --> Region: VA, Side: L, Electrode: 4 true region: VA
# ⚠️ Only 13 segments available. Skipping noise filtering.
# Loading microVA_L_5_CommonFiltered_lfs --> Region: VA, Side: L, Electrode: 5 true region: VA
# ⚠️ Only 13 segments available. Skipping noise filtering.
# Loading microVA_L_6_CommonFiltered_lfs --> Region: VA, Side: L, Electrode: 6 true region: VA
# ⚠️ Only 13 segments available. Skipping noise filtering.
# Loading microVA_R_4_CommonFiltered_lfs --> Region: VA, Side: R, Electrode: 4 true region: VA
# ⚠️ Only 13 segments available. Skipping noise filtering.
# Loading microVA_R_5_CommonFiltered_lfs --> Region: VA, Side: R, Electrode: 5 true region: VA
# ⚠️ Only 13 segments available. Skipping noise filtering.
# Loading microVA_R_6_CommonFiltered_lfs --> Region: VA, Side: R, Electrode: 6 true region: VA
# ⚠️ Only 13 segments available. Skipping noise filtering.
# Loading microVoSTN_L_1_CommonFiltered_lfs --> Region: VoSTN, Side: L, Electrode: 1 true region: STN
# ⚠️ Only 13 segments available. Skipping noise filtering.
# Loading microVoSTN_L_2_CommonFiltered_lfs --> Region: VoSTN, Side: L, Electrode: 2 true region: STN
# ⚠️ Only 13 segments available. Skipping noise filtering.
# Loading microVoSTN_L_3_CommonFiltered_lfs --> Region: VoSTN, Side: L, Electrode: 3 true region: STN
# ⚠️ Only 13 segments available. Skipping noise filtering.
# Loading microVoSTN_L_4_CommonFiltered_lfs --> Region: VoSTN, Side: L, Electrode: 4 true region: VO
# ⚠️ Only 13 segments available. Skipping noise filtering.
# Loading microVoSTN_L_5_CommonFiltered_lfs --> Region: VoSTN, Side: L, Electrode: 5 true region: VO
# ⚠️ Only 13 segments available. Skipping noise filtering.
# Loading microVoSTN_L_6_CommonFiltered_lfs --> Region: VoSTN, Side: L, Electrode: 6 true region: VO
# ⚠️ Only 13 segments available. Skipping noise filtering.
# Loading microVoSTN_R_1_CommonFiltered_lfs --> Region: VoSTN, Side: R, Electrode: 1 true region: STN
# ⚠️ Only 13 segments available. Skipping noise filtering.
# Loading microVoSTN_R_2_CommonFiltered_lfs --> Region: VoSTN, Side: R, Electrode: 2 true region: STN
# ⚠️ Only 13 segments available. Skipping noise filtering.
# Loading microVoSTN_R_3_CommonFiltered_lfs --> Region: VoSTN, Side: R, Electrode: 3 true region: STN
# ⚠️ Only 13 segments available. Skipping noise filtering.
# Loading microVoSTN_R_4_CommonFiltered_lfs --> Region: VoSTN, Side: R, Electrode: 4 true region: VO
# ⚠️ Only 13 segments available. Skipping noise filtering.
# Loading microVoSTN_R_5_CommonFiltered_lfs --> Region: VoSTN, Side: R, Electrode: 5 true region: VO
# ⚠️ Only 13 segments available. Skipping noise filtering.
# Loading microVoSTN_R_6_CommonFiltered_lfs --> Region: VoSTN, Side: R, Electrode: 6 true region: VO
# ⚠️ Only 13 segments available. Skipping noise filtering.
# Loading microVIM_L_4_CommonFiltered_lfs --> Region: VIM, Side: L, Electrode: 4 true region: VIM
# ⚠️ Only 13 segments available. Skipping noise filtering.
# Loading microVIM_L_5_CommonFiltered_lfs --> Region: VIM, Side: L, Electrode: 5 true region: VIM
# ⚠️ Only 13 segments available. Skipping noise filtering.
# Loading microVIM_L_6_CommonFiltered_lfs --> Region: VIM, Side: L, Electrode: 6 true region: VIM
# ⚠️ Only 13 segments available. Skipping noise filtering.
# Loading microVIM_R_4_CommonFiltered_lfs --> Region: VIM, Side: R, Electrode: 4 true region: VIM
# ⚠️ Only 13 segments available. Skipping noise filtering.
# Loading microVIM_R_5_CommonFiltered_lfs --> Region: VIM, Side: R, Electrode: 5 true region: VIM
# ⚠️ Only 13 segments available. Skipping noise filtering.
# Loading microVIM_R_6_CommonFiltered_lfs --> Region: VIM, Side: R, Electrode: 6 true region: VIM
# ⚠️ Only 13 segments available. Skipping noise filtering.
# held out channels :  {'GPi': 12, 'VA': 6, 'STN': 6, 'VO': 6, 'VIM': 6}
# Loading data from subject: S2 period: p3
# Loading microGPi1_L_4_CommonFiltered_lfs --> Region: GPi1, Side: L, Electrode: 4 true region: GPi
# ⚠️ Only 50 segments available. Skipping noise filtering.
# Loading microGPi1_L_5_CommonFiltered_lfs --> Region: GPi1, Side: L, Electrode: 5 true region: GPi
# ⚠️ Only 50 segments available. Skipping noise filtering.
# Loading microGPi1_L_6_CommonFiltered_lfs --> Region: GPi1, Side: L, Electrode: 6 true region: GPi
# ⚠️ Only 50 segments available. Skipping noise filtering.
# Loading microGPi1_R_4_CommonFiltered_lfs --> Region: GPi1, Side: R, Electrode: 4 true region: GPi
# ⚠️ Only 50 segments available. Skipping noise filtering.
# Loading microGPi1_R_5_CommonFiltered_lfs --> Region: GPi1, Side: R, Electrode: 5 true region: GPi
# ⚠️ Only 50 segments available. Skipping noise filtering.
# Loading microGPi1_R_6_CommonFiltered_lfs --> Region: GPi1, Side: R, Electrode: 6 true region: GPi
# ⚠️ Only 50 segments available. Skipping noise filtering.
# Loading microGPi2_L_4_CommonFiltered_lfs --> Region: GPi2, Side: L, Electrode: 4 true region: GPi
# ⚠️ Only 50 segments available. Skipping noise filtering.
# Loading microGPi2_L_5_CommonFiltered_lfs --> Region: GPi2, Side: L, Electrode: 5 true region: GPi
# ⚠️ Only 50 segments available. Skipping noise filtering.
# Loading microGPi2_L_6_CommonFiltered_lfs --> Region: GPi2, Side: L, Electrode: 6 true region: GPi
# ⚠️ Only 50 segments available. Skipping noise filtering.
# Loading microGPi2_R_4_CommonFiltered_lfs --> Region: GPi2, Side: R, Electrode: 4 true region: GPi
# ⚠️ Only 50 segments available. Skipping noise filtering.
# Loading microGPi2_R_5_CommonFiltered_lfs --> Region: GPi2, Side: R, Electrode: 5 true region: GPi
# ⚠️ Only 50 segments available. Skipping noise filtering.
# Loading microGPi2_R_6_CommonFiltered_lfs --> Region: GPi2, Side: R, Electrode: 6 true region: GPi
# ⚠️ Only 50 segments available. Skipping noise filtering.
# Loading microVA_L_4_CommonFiltered_lfs --> Region: VA, Side: L, Electrode: 4 true region: VA
# ⚠️ Only 50 segments available. Skipping noise filtering.
# Loading microVA_L_5_CommonFiltered_lfs --> Region: VA, Side: L, Electrode: 5 true region: VA
# ⚠️ Only 50 segments available. Skipping noise filtering.
# Loading microVA_L_6_CommonFiltered_lfs --> Region: VA, Side: L, Electrode: 6 true region: VA
# ⚠️ Only 50 segments available. Skipping noise filtering.
# Loading microVA_R_4_CommonFiltered_lfs --> Region: VA, Side: R, Electrode: 4 true region: VA
# ⚠️ Only 50 segments available. Skipping noise filtering.
# Loading microVA_R_5_CommonFiltered_lfs --> Region: VA, Side: R, Electrode: 5 true region: VA
# ⚠️ Only 50 segments available. Skipping noise filtering.
# Loading microVA_R_6_CommonFiltered_lfs --> Region: VA, Side: R, Electrode: 6 true region: VA
# ⚠️ Only 50 segments available. Skipping noise filtering.
# Loading microVoSTN_L_1_CommonFiltered_lfs --> Region: VoSTN, Side: L, Electrode: 1 true region: STN
# ⚠️ Only 50 segments available. Skipping noise filtering.
# Loading microVoSTN_L_2_CommonFiltered_lfs --> Region: VoSTN, Side: L, Electrode: 2 true region: STN
# ⚠️ Only 50 segments available. Skipping noise filtering.
# Loading microVoSTN_L_3_CommonFiltered_lfs --> Region: VoSTN, Side: L, Electrode: 3 true region: STN
# ⚠️ Only 50 segments available. Skipping noise filtering.
# Loading microVoSTN_L_4_CommonFiltered_lfs --> Region: VoSTN, Side: L, Electrode: 4 true region: VO
# ⚠️ Only 50 segments available. Skipping noise filtering.
# Loading microVoSTN_L_5_CommonFiltered_lfs --> Region: VoSTN, Side: L, Electrode: 5 true region: VO
# ⚠️ Only 50 segments available. Skipping noise filtering.
# Loading microVoSTN_L_6_CommonFiltered_lfs --> Region: VoSTN, Side: L, Electrode: 6 true region: VO
# ⚠️ Only 50 segments available. Skipping noise filtering.
# Loading microVoSTN_R_1_CommonFiltered_lfs --> Region: VoSTN, Side: R, Electrode: 1 true region: STN
# ⚠️ Only 50 segments available. Skipping noise filtering.
# Loading microVoSTN_R_2_CommonFiltered_lfs --> Region: VoSTN, Side: R, Electrode: 2 true region: STN
# ⚠️ Only 50 segments available. Skipping noise filtering.
# Loading microVoSTN_R_3_CommonFiltered_lfs --> Region: VoSTN, Side: R, Electrode: 3 true region: STN
# ⚠️ Only 50 segments available. Skipping noise filtering.
# Loading microVoSTN_R_4_CommonFiltered_lfs --> Region: VoSTN, Side: R, Electrode: 4 true region: VO
# ⚠️ Only 50 segments available. Skipping noise filtering.
# Loading microVoSTN_R_5_CommonFiltered_lfs --> Region: VoSTN, Side: R, Electrode: 5 true region: VO
# ⚠️ Only 50 segments available. Skipping noise filtering.
# Loading microVoSTN_R_6_CommonFiltered_lfs --> Region: VoSTN, Side: R, Electrode: 6 true region: VO
# ⚠️ Only 50 segments available. Skipping noise filtering.
# Loading microVIM_L_4_CommonFiltered_lfs --> Region: VIM, Side: L, Electrode: 4 true region: VIM
# ⚠️ Only 50 segments available. Skipping noise filtering.
# Loading microVIM_L_5_CommonFiltered_lfs --> Region: VIM, Side: L, Electrode: 5 true region: VIM
# ⚠️ Only 50 segments available. Skipping noise filtering.
# Loading microVIM_L_6_CommonFiltered_lfs --> Region: VIM, Side: L, Electrode: 6 true region: VIM
# ⚠️ Only 50 segments available. Skipping noise filtering.
# Loading microVIM_R_4_CommonFiltered_lfs --> Region: VIM, Side: R, Electrode: 4 true region: VIM
# ⚠️ Only 50 segments available. Skipping noise filtering.
# Loading microVIM_R_5_CommonFiltered_lfs --> Region: VIM, Side: R, Electrode: 5 true region: VIM
# ⚠️ Only 50 segments available. Skipping noise filtering.
# Loading microVIM_R_6_CommonFiltered_lfs --> Region: VIM, Side: R, Electrode: 6 true region: VIM
# ⚠️ Only 50 segments available. Skipping noise filtering.
# held out channels :  {'GPi': 12, 'VA': 6, 'STN': 6, 'VO': 6, 'VIM': 6}
# Loading data from subject: S2 period: p4
# Loading microGPi1_L_4_CommonFiltered_lfs --> Region: GPi1, Side: L, Electrode: 4 true region: GPi
# ⚠️ Only 65 segments available. Skipping noise filtering.
# Loading microGPi1_L_5_CommonFiltered_lfs --> Region: GPi1, Side: L, Electrode: 5 true region: GPi
# ⚠️ Only 65 segments available. Skipping noise filtering.
# Loading microGPi1_L_6_CommonFiltered_lfs --> Region: GPi1, Side: L, Electrode: 6 true region: GPi
# ⚠️ Only 65 segments available. Skipping noise filtering.
# Loading microGPi1_R_4_CommonFiltered_lfs --> Region: GPi1, Side: R, Electrode: 4 true region: GPi
# ⚠️ Only 65 segments available. Skipping noise filtering.
# Loading microGPi1_R_5_CommonFiltered_lfs --> Region: GPi1, Side: R, Electrode: 5 true region: GPi
# ⚠️ Only 65 segments available. Skipping noise filtering.
# Loading microGPi1_R_6_CommonFiltered_lfs --> Region: GPi1, Side: R, Electrode: 6 true region: GPi
# ⚠️ Only 65 segments available. Skipping noise filtering.
# Loading microGPi2_L_4_CommonFiltered_lfs --> Region: GPi2, Side: L, Electrode: 4 true region: GPi
# ⚠️ Only 65 segments available. Skipping noise filtering.
# Loading microGPi2_L_5_CommonFiltered_lfs --> Region: GPi2, Side: L, Electrode: 5 true region: GPi
# ⚠️ Only 65 segments available. Skipping noise filtering.
# Loading microGPi2_L_6_CommonFiltered_lfs --> Region: GPi2, Side: L, Electrode: 6 true region: GPi
# ⚠️ Only 65 segments available. Skipping noise filtering.
# Loading microGPi2_R_4_CommonFiltered_lfs --> Region: GPi2, Side: R, Electrode: 4 true region: GPi
# ⚠️ Only 65 segments available. Skipping noise filtering.
# Loading microGPi2_R_5_CommonFiltered_lfs --> Region: GPi2, Side: R, Electrode: 5 true region: GPi
# ⚠️ Only 65 segments available. Skipping noise filtering.
# Loading microGPi2_R_6_CommonFiltered_lfs --> Region: GPi2, Side: R, Electrode: 6 true region: GPi
# ⚠️ Only 65 segments available. Skipping noise filtering.
# Loading microVA_L_4_CommonFiltered_lfs --> Region: VA, Side: L, Electrode: 4 true region: VA
# ⚠️ Only 65 segments available. Skipping noise filtering.
# Loading microVA_L_5_CommonFiltered_lfs --> Region: VA, Side: L, Electrode: 5 true region: VA
# ⚠️ Only 65 segments available. Skipping noise filtering.
# Loading microVA_L_6_CommonFiltered_lfs --> Region: VA, Side: L, Electrode: 6 true region: VA
# ⚠️ Only 65 segments available. Skipping noise filtering.
# Loading microVA_R_4_CommonFiltered_lfs --> Region: VA, Side: R, Electrode: 4 true region: VA
# ⚠️ Only 65 segments available. Skipping noise filtering.
# Loading microVA_R_5_CommonFiltered_lfs --> Region: VA, Side: R, Electrode: 5 true region: VA
# ⚠️ Only 65 segments available. Skipping noise filtering.
# Loading microVA_R_6_CommonFiltered_lfs --> Region: VA, Side: R, Electrode: 6 true region: VA
# ⚠️ Only 65 segments available. Skipping noise filtering.
# Loading microVoSTN_L_1_CommonFiltered_lfs --> Region: VoSTN, Side: L, Electrode: 1 true region: STN
# ⚠️ Only 65 segments available. Skipping noise filtering.
# Loading microVoSTN_L_2_CommonFiltered_lfs --> Region: VoSTN, Side: L, Electrode: 2 true region: STN
# ⚠️ Only 65 segments available. Skipping noise filtering.
# Loading microVoSTN_L_3_CommonFiltered_lfs --> Region: VoSTN, Side: L, Electrode: 3 true region: STN
# ⚠️ Only 65 segments available. Skipping noise filtering.
# Loading microVoSTN_L_4_CommonFiltered_lfs --> Region: VoSTN, Side: L, Electrode: 4 true region: VO
# ⚠️ Only 65 segments available. Skipping noise filtering.
# Loading microVoSTN_L_5_CommonFiltered_lfs --> Region: VoSTN, Side: L, Electrode: 5 true region: VO
# ⚠️ Only 65 segments available. Skipping noise filtering.
# Loading microVoSTN_L_6_CommonFiltered_lfs --> Region: VoSTN, Side: L, Electrode: 6 true region: VO
# ⚠️ Only 65 segments available. Skipping noise filtering.
# Loading microVoSTN_R_1_CommonFiltered_lfs --> Region: VoSTN, Side: R, Electrode: 1 true region: STN
# ⚠️ Only 65 segments available. Skipping noise filtering.
# Loading microVoSTN_R_2_CommonFiltered_lfs --> Region: VoSTN, Side: R, Electrode: 2 true region: STN
# ⚠️ Only 65 segments available. Skipping noise filtering.
# Loading microVoSTN_R_3_CommonFiltered_lfs --> Region: VoSTN, Side: R, Electrode: 3 true region: STN
# ⚠️ Only 65 segments available. Skipping noise filtering.
# Loading microVoSTN_R_4_CommonFiltered_lfs --> Region: VoSTN, Side: R, Electrode: 4 true region: VO
# ⚠️ Only 65 segments available. Skipping noise filtering.
# Loading microVoSTN_R_5_CommonFiltered_lfs --> Region: VoSTN, Side: R, Electrode: 5 true region: VO
# ⚠️ Only 65 segments available. Skipping noise filtering.
# Loading microVoSTN_R_6_CommonFiltered_lfs --> Region: VoSTN, Side: R, Electrode: 6 true region: VO
# ⚠️ Only 65 segments available. Skipping noise filtering.
# Loading microVIM_L_4_CommonFiltered_lfs --> Region: VIM, Side: L, Electrode: 4 true region: VIM
# ⚠️ Only 65 segments available. Skipping noise filtering.
# Loading microVIM_L_5_CommonFiltered_lfs --> Region: VIM, Side: L, Electrode: 5 true region: VIM
# ⚠️ Only 65 segments available. Skipping noise filtering.
# Loading microVIM_L_6_CommonFiltered_lfs --> Region: VIM, Side: L, Electrode: 6 true region: VIM
# ⚠️ Only 65 segments available. Skipping noise filtering.
# Loading microVIM_R_4_CommonFiltered_lfs --> Region: VIM, Side: R, Electrode: 4 true region: VIM
# ⚠️ Only 65 segments available. Skipping noise filtering.
# Loading microVIM_R_5_CommonFiltered_lfs --> Region: VIM, Side: R, Electrode: 5 true region: VIM
# ⚠️ Only 65 segments available. Skipping noise filtering.
# Loading microVIM_R_6_CommonFiltered_lfs --> Region: VIM, Side: R, Electrode: 6 true region: VIM
# ⚠️ Only 65 segments available. Skipping noise filtering.
# held out channels :  {'GPi': 12, 'VA': 6, 'STN': 6, 'VO': 6, 'VIM': 6}
# Loading data from subject: S3 period: p9
# Loading microGPi1_L_4_CommonFiltered_lfs --> Region: GPi1, Side: L, Electrode: 4 true region: GPi
# ⚠️ Only 79 segments available. Skipping noise filtering.
# Loading microGPi1_L_5_CommonFiltered_lfs --> Region: GPi1, Side: L, Electrode: 5 true region: GPi
# ⚠️ Only 79 segments available. Skipping noise filtering.
# Loading microGPi1_L_6_CommonFiltered_lfs --> Region: GPi1, Side: L, Electrode: 6 true region: GPi
# ⚠️ Only 79 segments available. Skipping noise filtering.
# Loading microGPi1_R_4_CommonFiltered_lfs --> Region: GPi1, Side: R, Electrode: 4 true region: GPi
# ⚠️ Only 79 segments available. Skipping noise filtering.
# Loading microGPi1_R_5_CommonFiltered_lfs --> Region: GPi1, Side: R, Electrode: 5 true region: GPi
# ⚠️ Only 79 segments available. Skipping noise filtering.
# Loading microGPi1_R_6_CommonFiltered_lfs --> Region: GPi1, Side: R, Electrode: 6 true region: GPi
# ⚠️ Only 79 segments available. Skipping noise filtering.
# Loading microGPi2_L_4_CommonFiltered_lfs --> Region: GPi2, Side: L, Electrode: 4 true region: GPi
# ⚠️ Only 79 segments available. Skipping noise filtering.
# Loading microGPi2_L_5_CommonFiltered_lfs --> Region: GPi2, Side: L, Electrode: 5 true region: GPi
# ⚠️ Only 79 segments available. Skipping noise filtering.
# Loading microGPi2_L_6_CommonFiltered_lfs --> Region: GPi2, Side: L, Electrode: 6 true region: GPi
# ⚠️ Only 79 segments available. Skipping noise filtering.
# Loading microGPi2_R_4_CommonFiltered_lfs --> Region: GPi2, Side: R, Electrode: 4 true region: GPi
# ⚠️ Only 79 segments available. Skipping noise filtering.
# Loading microGPi2_R_5_CommonFiltered_lfs --> Region: GPi2, Side: R, Electrode: 5 true region: GPi
# ⚠️ Only 79 segments available. Skipping noise filtering.
# Loading microGPi2_R_6_CommonFiltered_lfs --> Region: GPi2, Side: R, Electrode: 6 true region: GPi
# ⚠️ Only 79 segments available. Skipping noise filtering.
# Loading microVA_L_4_CommonFiltered_lfs --> Region: VA, Side: L, Electrode: 4 true region: VA
# ⚠️ Only 79 segments available. Skipping noise filtering.
# Loading microVA_L_5_CommonFiltered_lfs --> Region: VA, Side: L, Electrode: 5 true region: VA
# ⚠️ Only 79 segments available. Skipping noise filtering.
# Loading microVA_L_6_CommonFiltered_lfs --> Region: VA, Side: L, Electrode: 6 true region: VA
# ⚠️ Only 79 segments available. Skipping noise filtering.
# Loading microVA_R_4_CommonFiltered_lfs --> Region: VA, Side: R, Electrode: 4 true region: VA
# ⚠️ Only 79 segments available. Skipping noise filtering.
# Loading microVA_R_5_CommonFiltered_lfs --> Region: VA, Side: R, Electrode: 5 true region: VA
# ⚠️ Only 79 segments available. Skipping noise filtering.
# Loading microVA_R_6_CommonFiltered_lfs --> Region: VA, Side: R, Electrode: 6 true region: VA
# ⚠️ Only 79 segments available. Skipping noise filtering.
# Loading microVoSTN_L_1_CommonFiltered_lfs --> Region: VoSTN, Side: L, Electrode: 1 true region: STN
# ⚠️ Only 79 segments available. Skipping noise filtering.
# Loading microVoSTN_L_2_CommonFiltered_lfs --> Region: VoSTN, Side: L, Electrode: 2 true region: STN
# ⚠️ Only 79 segments available. Skipping noise filtering.
# Loading microVoSTN_L_3_CommonFiltered_lfs --> Region: VoSTN, Side: L, Electrode: 3 true region: STN
# ⚠️ Only 79 segments available. Skipping noise filtering.
# Loading microVoSTN_L_4_CommonFiltered_lfs --> Region: VoSTN, Side: L, Electrode: 4 true region: VO
# ⚠️ Only 79 segments available. Skipping noise filtering.
# Loading microVoSTN_L_5_CommonFiltered_lfs --> Region: VoSTN, Side: L, Electrode: 5 true region: VO
# ⚠️ Only 79 segments available. Skipping noise filtering.
# Loading microVoSTN_L_6_CommonFiltered_lfs --> Region: VoSTN, Side: L, Electrode: 6 true region: VO
# ⚠️ Only 79 segments available. Skipping noise filtering.
# Loading microVoSTN_R_1_CommonFiltered_lfs --> Region: VoSTN, Side: R, Electrode: 1 true region: STN
# ⚠️ Only 79 segments available. Skipping noise filtering.
# Loading microVoSTN_R_2_CommonFiltered_lfs --> Region: VoSTN, Side: R, Electrode: 2 true region: STN
# ⚠️ Only 79 segments available. Skipping noise filtering.
# Loading microVoSTN_R_3_CommonFiltered_lfs --> Region: VoSTN, Side: R, Electrode: 3 true region: STN
# ⚠️ Only 79 segments available. Skipping noise filtering.
# Loading microVoSTN_R_4_CommonFiltered_lfs --> Region: VoSTN, Side: R, Electrode: 4 true region: VO
# ⚠️ Only 79 segments available. Skipping noise filtering.
# Loading microVoSTN_R_5_CommonFiltered_lfs --> Region: VoSTN, Side: R, Electrode: 5 true region: VO
# ⚠️ Only 79 segments available. Skipping noise filtering.
# Loading microVoSTN_R_6_CommonFiltered_lfs --> Region: VoSTN, Side: R, Electrode: 6 true region: VO
# ⚠️ Only 79 segments available. Skipping noise filtering.
# Loading microVIM_L_4_CommonFiltered_lfs --> Region: VIM, Side: L, Electrode: 4 true region: VIM
# ⚠️ Only 79 segments available. Skipping noise filtering.
# Loading microVIM_L_5_CommonFiltered_lfs --> Region: VIM, Side: L, Electrode: 5 true region: VIM
# ⚠️ Only 79 segments available. Skipping noise filtering.
# Loading microVIM_L_6_CommonFiltered_lfs --> Region: VIM, Side: L, Electrode: 6 true region: VIM
# ⚠️ Only 79 segments available. Skipping noise filtering.
# Loading microVIM_R_4_CommonFiltered_lfs --> Region: VIM, Side: R, Electrode: 4 true region: VIM
# ⚠️ Only 79 segments available. Skipping noise filtering.
# Loading microVIM_R_5_CommonFiltered_lfs --> Region: VIM, Side: R, Electrode: 5 true region: VIM
# ⚠️ Only 79 segments available. Skipping noise filtering.
# Loading microVIM_R_6_CommonFiltered_lfs --> Region: VIM, Side: R, Electrode: 6 true region: VIM
# ⚠️ Only 79 segments available. Skipping noise filtering.
# held out channels :  {'GPi': 12, 'VA': 6, 'STN': 6, 'VO': 6, 'VIM': 6}
# Loading data from subject: S3 period: p10
# Loading microGPi1_L_4_CommonFiltered_lfs --> Region: GPi1, Side: L, Electrode: 4 true region: GPi
# ⚠️ Only 38 segments available. Skipping noise filtering.
# Loading microGPi1_L_5_CommonFiltered_lfs --> Region: GPi1, Side: L, Electrode: 5 true region: GPi
# ⚠️ Only 38 segments available. Skipping noise filtering.
# Loading microGPi1_L_6_CommonFiltered_lfs --> Region: GPi1, Side: L, Electrode: 6 true region: GPi
# ⚠️ Only 38 segments available. Skipping noise filtering.
# Loading microGPi1_R_4_CommonFiltered_lfs --> Region: GPi1, Side: R, Electrode: 4 true region: GPi
# ⚠️ Only 38 segments available. Skipping noise filtering.
# Loading microGPi1_R_5_CommonFiltered_lfs --> Region: GPi1, Side: R, Electrode: 5 true region: GPi
# ⚠️ Only 38 segments available. Skipping noise filtering.
# Loading microGPi1_R_6_CommonFiltered_lfs --> Region: GPi1, Side: R, Electrode: 6 true region: GPi
# ⚠️ Only 38 segments available. Skipping noise filtering.
# Loading microGPi2_L_4_CommonFiltered_lfs --> Region: GPi2, Side: L, Electrode: 4 true region: GPi
# ⚠️ Only 38 segments available. Skipping noise filtering.
# Loading microGPi2_L_5_CommonFiltered_lfs --> Region: GPi2, Side: L, Electrode: 5 true region: GPi
# ⚠️ Only 38 segments available. Skipping noise filtering.
# Loading microGPi2_L_6_CommonFiltered_lfs --> Region: GPi2, Side: L, Electrode: 6 true region: GPi
# ⚠️ Only 38 segments available. Skipping noise filtering.
# Loading microGPi2_R_4_CommonFiltered_lfs --> Region: GPi2, Side: R, Electrode: 4 true region: GPi
# ⚠️ Only 38 segments available. Skipping noise filtering.
# Loading microGPi2_R_5_CommonFiltered_lfs --> Region: GPi2, Side: R, Electrode: 5 true region: GPi
# ⚠️ Only 38 segments available. Skipping noise filtering.
# Loading microGPi2_R_6_CommonFiltered_lfs --> Region: GPi2, Side: R, Electrode: 6 true region: GPi
# ⚠️ Only 38 segments available. Skipping noise filtering.
# Loading microVA_L_4_CommonFiltered_lfs --> Region: VA, Side: L, Electrode: 4 true region: VA
# ⚠️ Only 38 segments available. Skipping noise filtering.
# Loading microVA_L_5_CommonFiltered_lfs --> Region: VA, Side: L, Electrode: 5 true region: VA
# ⚠️ Only 38 segments available. Skipping noise filtering.
# Loading microVA_L_6_CommonFiltered_lfs --> Region: VA, Side: L, Electrode: 6 true region: VA
# ⚠️ Only 38 segments available. Skipping noise filtering.
# Loading microVA_R_4_CommonFiltered_lfs --> Region: VA, Side: R, Electrode: 4 true region: VA
# ⚠️ Only 38 segments available. Skipping noise filtering.
# Loading microVA_R_5_CommonFiltered_lfs --> Region: VA, Side: R, Electrode: 5 true region: VA
# ⚠️ Only 38 segments available. Skipping noise filtering.
# Loading microVA_R_6_CommonFiltered_lfs --> Region: VA, Side: R, Electrode: 6 true region: VA
# ⚠️ Only 38 segments available. Skipping noise filtering.
# Loading microVoSTN_L_1_CommonFiltered_lfs --> Region: VoSTN, Side: L, Electrode: 1 true region: STN
# ⚠️ Only 38 segments available. Skipping noise filtering.
# Loading microVoSTN_L_2_CommonFiltered_lfs --> Region: VoSTN, Side: L, Electrode: 2 true region: STN
# ⚠️ Only 38 segments available. Skipping noise filtering.
# Loading microVoSTN_L_3_CommonFiltered_lfs --> Region: VoSTN, Side: L, Electrode: 3 true region: STN
# ⚠️ Only 38 segments available. Skipping noise filtering.
# Loading microVoSTN_L_4_CommonFiltered_lfs --> Region: VoSTN, Side: L, Electrode: 4 true region: VO
# ⚠️ Only 38 segments available. Skipping noise filtering.
# Loading microVoSTN_L_5_CommonFiltered_lfs --> Region: VoSTN, Side: L, Electrode: 5 true region: VO
# ⚠️ Only 38 segments available. Skipping noise filtering.
# Loading microVoSTN_L_6_CommonFiltered_lfs --> Region: VoSTN, Side: L, Electrode: 6 true region: VO
# ⚠️ Only 38 segments available. Skipping noise filtering.
# Loading microVoSTN_R_1_CommonFiltered_lfs --> Region: VoSTN, Side: R, Electrode: 1 true region: STN
# ⚠️ Only 38 segments available. Skipping noise filtering.
# Loading microVoSTN_R_2_CommonFiltered_lfs --> Region: VoSTN, Side: R, Electrode: 2 true region: STN
# ⚠️ Only 38 segments available. Skipping noise filtering.
# Loading microVoSTN_R_3_CommonFiltered_lfs --> Region: VoSTN, Side: R, Electrode: 3 true region: STN
# ⚠️ Only 38 segments available. Skipping noise filtering.
# Loading microVoSTN_R_4_CommonFiltered_lfs --> Region: VoSTN, Side: R, Electrode: 4 true region: VO
# ⚠️ Only 38 segments available. Skipping noise filtering.
# Loading microVoSTN_R_5_CommonFiltered_lfs --> Region: VoSTN, Side: R, Electrode: 5 true region: VO
# ⚠️ Only 38 segments available. Skipping noise filtering.
# Loading microVoSTN_R_6_CommonFiltered_lfs --> Region: VoSTN, Side: R, Electrode: 6 true region: VO
# ⚠️ Only 38 segments available. Skipping noise filtering.
# Loading microVIM_L_4_CommonFiltered_lfs --> Region: VIM, Side: L, Electrode: 4 true region: VIM
# ⚠️ Only 38 segments available. Skipping noise filtering.
# Loading microVIM_L_5_CommonFiltered_lfs --> Region: VIM, Side: L, Electrode: 5 true region: VIM
# ⚠️ Only 38 segments available. Skipping noise filtering.
# Loading microVIM_L_6_CommonFiltered_lfs --> Region: VIM, Side: L, Electrode: 6 true region: VIM
# ⚠️ Only 38 segments available. Skipping noise filtering.
# Loading microVIM_R_4_CommonFiltered_lfs --> Region: VIM, Side: R, Electrode: 4 true region: VIM
# ⚠️ Only 38 segments available. Skipping noise filtering.
# Loading microVIM_R_5_CommonFiltered_lfs --> Region: VIM, Side: R, Electrode: 5 true region: VIM
# ⚠️ Only 38 segments available. Skipping noise filtering.
# Loading microVIM_R_6_CommonFiltered_lfs --> Region: VIM, Side: R, Electrode: 6 true region: VIM
# ⚠️ Only 38 segments available. Skipping noise filtering.
# held out channels :  {'GPi': 12, 'VA': 6, 'STN': 6, 'VO': 6, 'VIM': 6}
# Loading data from subject: S3 period: p11
# Loading microGPi1_L_4_CommonFiltered_lfs --> Region: GPi1, Side: L, Electrode: 4 true region: GPi
# ⚠️ Only 16 segments available. Skipping noise filtering.
# Loading microGPi1_L_5_CommonFiltered_lfs --> Region: GPi1, Side: L, Electrode: 5 true region: GPi
# ⚠️ Only 16 segments available. Skipping noise filtering.
# Loading microGPi1_L_6_CommonFiltered_lfs --> Region: GPi1, Side: L, Electrode: 6 true region: GPi
# ⚠️ Only 16 segments available. Skipping noise filtering.
# Loading microGPi1_R_4_CommonFiltered_lfs --> Region: GPi1, Side: R, Electrode: 4 true region: GPi
# ⚠️ Only 16 segments available. Skipping noise filtering.
# Loading microGPi1_R_5_CommonFiltered_lfs --> Region: GPi1, Side: R, Electrode: 5 true region: GPi
# ⚠️ Only 16 segments available. Skipping noise filtering.
# Loading microGPi1_R_6_CommonFiltered_lfs --> Region: GPi1, Side: R, Electrode: 6 true region: GPi
# ⚠️ Only 16 segments available. Skipping noise filtering.
# Loading microGPi2_L_4_CommonFiltered_lfs --> Region: GPi2, Side: L, Electrode: 4 true region: GPi
# ⚠️ Only 16 segments available. Skipping noise filtering.
# Loading microGPi2_L_5_CommonFiltered_lfs --> Region: GPi2, Side: L, Electrode: 5 true region: GPi
# ⚠️ Only 16 segments available. Skipping noise filtering.
# Loading microGPi2_L_6_CommonFiltered_lfs --> Region: GPi2, Side: L, Electrode: 6 true region: GPi
# ⚠️ Only 16 segments available. Skipping noise filtering.
# Loading microGPi2_R_4_CommonFiltered_lfs --> Region: GPi2, Side: R, Electrode: 4 true region: GPi
# ⚠️ Only 16 segments available. Skipping noise filtering.
# Loading microGPi2_R_5_CommonFiltered_lfs --> Region: GPi2, Side: R, Electrode: 5 true region: GPi
# ⚠️ Only 16 segments available. Skipping noise filtering.
# Loading microGPi2_R_6_CommonFiltered_lfs --> Region: GPi2, Side: R, Electrode: 6 true region: GPi
# ⚠️ Only 16 segments available. Skipping noise filtering.
# Loading microVA_L_4_CommonFiltered_lfs --> Region: VA, Side: L, Electrode: 4 true region: VA
# ⚠️ Only 16 segments available. Skipping noise filtering.
# Loading microVA_L_5_CommonFiltered_lfs --> Region: VA, Side: L, Electrode: 5 true region: VA
# ⚠️ Only 16 segments available. Skipping noise filtering.
# Loading microVA_L_6_CommonFiltered_lfs --> Region: VA, Side: L, Electrode: 6 true region: VA
# ⚠️ Only 16 segments available. Skipping noise filtering.
# Loading microVA_R_4_CommonFiltered_lfs --> Region: VA, Side: R, Electrode: 4 true region: VA
# ⚠️ Only 16 segments available. Skipping noise filtering.
# Loading microVA_R_5_CommonFiltered_lfs --> Region: VA, Side: R, Electrode: 5 true region: VA
# ⚠️ Only 16 segments available. Skipping noise filtering.
# Loading microVA_R_6_CommonFiltered_lfs --> Region: VA, Side: R, Electrode: 6 true region: VA
# ⚠️ Only 16 segments available. Skipping noise filtering.
# Loading microVoSTN_L_1_CommonFiltered_lfs --> Region: VoSTN, Side: L, Electrode: 1 true region: STN
# ⚠️ Only 16 segments available. Skipping noise filtering.
# Loading microVoSTN_L_2_CommonFiltered_lfs --> Region: VoSTN, Side: L, Electrode: 2 true region: STN
# ⚠️ Only 16 segments available. Skipping noise filtering.
# Loading microVoSTN_L_3_CommonFiltered_lfs --> Region: VoSTN, Side: L, Electrode: 3 true region: STN
# ⚠️ Only 16 segments available. Skipping noise filtering.
# Loading microVoSTN_L_4_CommonFiltered_lfs --> Region: VoSTN, Side: L, Electrode: 4 true region: VO
# ⚠️ Only 16 segments available. Skipping noise filtering.
# Loading microVoSTN_L_5_CommonFiltered_lfs --> Region: VoSTN, Side: L, Electrode: 5 true region: VO
# ⚠️ Only 16 segments available. Skipping noise filtering.
# Loading microVoSTN_L_6_CommonFiltered_lfs --> Region: VoSTN, Side: L, Electrode: 6 true region: VO
# ⚠️ Only 16 segments available. Skipping noise filtering.
# Loading microVoSTN_R_1_CommonFiltered_lfs --> Region: VoSTN, Side: R, Electrode: 1 true region: STN
# ⚠️ Only 16 segments available. Skipping noise filtering.
# Loading microVoSTN_R_2_CommonFiltered_lfs --> Region: VoSTN, Side: R, Electrode: 2 true region: STN
# ⚠️ Only 16 segments available. Skipping noise filtering.
# Loading microVoSTN_R_3_CommonFiltered_lfs --> Region: VoSTN, Side: R, Electrode: 3 true region: STN
# ⚠️ Only 16 segments available. Skipping noise filtering.
# Loading microVoSTN_R_4_CommonFiltered_lfs --> Region: VoSTN, Side: R, Electrode: 4 true region: VO
# ⚠️ Only 16 segments available. Skipping noise filtering.
# Loading microVoSTN_R_5_CommonFiltered_lfs --> Region: VoSTN, Side: R, Electrode: 5 true region: VO
# ⚠️ Only 16 segments available. Skipping noise filtering.
# Loading microVoSTN_R_6_CommonFiltered_lfs --> Region: VoSTN, Side: R, Electrode: 6 true region: VO
# ⚠️ Only 16 segments available. Skipping noise filtering.
# Loading microVIM_L_4_CommonFiltered_lfs --> Region: VIM, Side: L, Electrode: 4 true region: VIM
# ⚠️ Only 16 segments available. Skipping noise filtering.
# Loading microVIM_L_5_CommonFiltered_lfs --> Region: VIM, Side: L, Electrode: 5 true region: VIM
# ⚠️ Only 16 segments available. Skipping noise filtering.
# Loading microVIM_L_6_CommonFiltered_lfs --> Region: VIM, Side: L, Electrode: 6 true region: VIM
# ⚠️ Only 16 segments available. Skipping noise filtering.
# Loading microVIM_R_4_CommonFiltered_lfs --> Region: VIM, Side: R, Electrode: 4 true region: VIM
# ⚠️ Only 16 segments available. Skipping noise filtering.
# Loading microVIM_R_5_CommonFiltered_lfs --> Region: VIM, Side: R, Electrode: 5 true region: VIM
# ⚠️ Only 16 segments available. Skipping noise filtering.
# Loading microVIM_R_6_CommonFiltered_lfs --> Region: VIM, Side: R, Electrode: 6 true region: VIM
# ⚠️ Only 16 segments available. Skipping noise filtering.
# held out channels :  {'GPi': 12, 'VA': 6, 'STN': 6, 'VO': 6, 'VIM': 6}
# Loading data from subject: S4 period: p4
# Loading microGPi1_L_4_CommonFiltered_lfs --> Region: GPi1, Side: L, Electrode: 4 true region: GPi
# ⚠️ Only 40 segments available. Skipping noise filtering.
# Loading microGPi1_L_5_CommonFiltered_lfs --> Region: GPi1, Side: L, Electrode: 5 true region: GPi
# ⚠️ Only 40 segments available. Skipping noise filtering.
# Loading microGPi1_L_6_CommonFiltered_lfs --> Region: GPi1, Side: L, Electrode: 6 true region: GPi
# ⚠️ Only 40 segments available. Skipping noise filtering.
# Loading microGPi1_R_4_CommonFiltered_lfs --> Region: GPi1, Side: R, Electrode: 4 true region: GPi
# ⚠️ Only 40 segments available. Skipping noise filtering.
# Loading microGPi1_R_5_CommonFiltered_lfs --> Region: GPi1, Side: R, Electrode: 5 true region: GPi
# ⚠️ Only 40 segments available. Skipping noise filtering.
# Loading microGPi1_R_6_CommonFiltered_lfs --> Region: GPi1, Side: R, Electrode: 6 true region: GPi
# ⚠️ Only 40 segments available. Skipping noise filtering.
# Loading microGPi2_L_4_CommonFiltered_lfs --> Region: GPi2, Side: L, Electrode: 4 true region: GPi
# ⚠️ Only 40 segments available. Skipping noise filtering.
# Loading microGPi2_L_5_CommonFiltered_lfs --> Region: GPi2, Side: L, Electrode: 5 true region: GPi
# ⚠️ Only 40 segments available. Skipping noise filtering.
# Loading microGPi2_L_6_CommonFiltered_lfs --> Region: GPi2, Side: L, Electrode: 6 true region: GPi
# ⚠️ Only 40 segments available. Skipping noise filtering.
# Loading microGPi2_R_4_CommonFiltered_lfs --> Region: GPi2, Side: R, Electrode: 4 true region: GPi
# ⚠️ Only 40 segments available. Skipping noise filtering.
# Loading microGPi2_R_5_CommonFiltered_lfs --> Region: GPi2, Side: R, Electrode: 5 true region: GPi
# ⚠️ Only 40 segments available. Skipping noise filtering.
# ...
# Epoch 103 SupCon Train Loss: 0.9708
# Epoch 103 PairEval Acc: 0.5919  (loss 0.5729)
# Epoch 103/200 - LR: 0.001000 - Train: 0.9708 - Val: 0.5729 (acc 0.592)
# Epoch 104 SupCon Train Loss: 0.9615
# Epoch 104 PairEval Acc: 0.5963  (loss 0.5456)
# Epoch 104/200 - LR: 0.001000 - Train: 0.9615 - Val: 0.5456 (acc 0.596)
# Epoch 105 SupCon Train Loss: 0.9615
# Epoch 105 PairEval Acc: 0.5897  (loss 0.5555)
# Epoch 105/200 - LR: 0.001000 - Train: 0.9615 - Val: 0.5555 (acc 0.590)
# Epoch 106 SupCon Train Loss: 0.9684
# Epoch 106 PairEval Acc: 0.5959  (loss 0.5658)
# Epoch 106/200 - LR: 0.001000 - Train: 0.9684 - Val: 0.5658 (acc 0.596)
# Epoch 107 SupCon Train Loss: 0.9579
# Epoch 107 PairEval Acc: 0.5914  (loss 0.5668)
# Epoch 107/200 - LR: 0.001000 - Train: 0.9579 - Val: 0.5668 (acc 0.591)
# Epoch 108 SupCon Train Loss: 0.9613
# Epoch 108 PairEval Acc: 0.6055  (loss 0.5450)
# Epoch 108/200 - LR: 0.001000 - Train: 0.9613 - Val: 0.5450 (acc 0.606)
#   New best model saved at epoch 108
# Epoch 109 SupCon Train Loss: 0.9597
# Epoch 109 PairEval Acc: 0.5973  (loss 0.5664)
# Epoch 109/200 - LR: 0.001000 - Train: 0.9597 - Val: 0.5664 (acc 0.597)
# Epoch 110 SupCon Train Loss: 0.9565
# Epoch 110 PairEval Acc: 0.5897  (loss 0.5591)
# Epoch 110/200 - LR: 0.001000 - Train: 0.9565 - Val: 0.5591 (acc 0.590)
# Epoch 111 SupCon Train Loss: 0.9544
# Epoch 111 PairEval Acc: 0.5879  (loss 0.5873)
# Epoch 111/200 - LR: 0.001000 - Train: 0.9544 - Val: 0.5873 (acc 0.588)
# Epoch 112 SupCon Train Loss: 0.9489
# Epoch 112 PairEval Acc: 0.5992  (loss 0.5466)
# Epoch 112/200 - LR: 0.001000 - Train: 0.9489 - Val: 0.5466 (acc 0.599)
# Epoch 113 SupCon Train Loss: 0.9443
# Epoch 113 PairEval Acc: 0.5929  (loss 0.5681)
# Epoch 113/200 - LR: 0.001000 - Train: 0.9443 - Val: 0.5681 (acc 0.593)
# Epoch 114 SupCon Train Loss: 0.9469
# Epoch 114 PairEval Acc: 0.5931  (loss 0.5637)
# Epoch 114/200 - LR: 0.001000 - Train: 0.9469 - Val: 0.5637 (acc 0.593)
# Epoch 115 SupCon Train Loss: 0.9415
# Epoch 115 PairEval Acc: 0.5976  (loss 0.5630)
# Epoch 115/200 - LR: 0.001000 - Train: 0.9415 - Val: 0.5630 (acc 0.598)
# Epoch 116 SupCon Train Loss: 0.9422
# Epoch 116 PairEval Acc: 0.5851  (loss 0.5858)
# Epoch 116/200 - LR: 0.001000 - Train: 0.9422 - Val: 0.5858 (acc 0.585)
# Epoch 117 SupCon Train Loss: 0.9354
# Epoch 117 PairEval Acc: 0.5951  (loss 0.5578)
# Epoch 117/200 - LR: 0.001000 - Train: 0.9354 - Val: 0.5578 (acc 0.595)
# Epoch 118 SupCon Train Loss: 0.9368
# Epoch 118 PairEval Acc: 0.6006  (loss 0.5406)
# Epoch 118/200 - LR: 0.001000 - Train: 0.9368 - Val: 0.5406 (acc 0.601)
# Epoch 119 SupCon Train Loss: 0.9389
# Epoch 119 PairEval Acc: 0.5911  (loss 0.5720)
# Epoch 119/200 - LR: 0.001000 - Train: 0.9389 - Val: 0.5720 (acc 0.591)
# Epoch 120 SupCon Train Loss: 0.9293
# Epoch 120 PairEval Acc: 0.5971  (loss 0.5645)
# Epoch 120/200 - LR: 0.001000 - Train: 0.9293 - Val: 0.5645 (acc 0.597)
# Epoch 121 SupCon Train Loss: 0.9302
# Epoch 121 PairEval Acc: 0.5973  (loss 0.5463)
# Epoch 121/200 - LR: 0.001000 - Train: 0.9302 - Val: 0.5463 (acc 0.597)
# Epoch 122 SupCon Train Loss: 0.9235
# Epoch 122 PairEval Acc: 0.6013  (loss 0.5585)
# Epoch 122/200 - LR: 0.001000 - Train: 0.9235 - Val: 0.5585 (acc 0.601)
# Epoch 123 SupCon Train Loss: 0.9316
# Epoch 123 PairEval Acc: 0.6015  (loss 0.5529)
# Epoch 123/200 - LR: 0.001000 - Train: 0.9316 - Val: 0.5529 (acc 0.602)
# Epoch 124 SupCon Train Loss: 0.9268
# Epoch 124 PairEval Acc: 0.6066  (loss 0.5488)
# Epoch 124/200 - LR: 0.001000 - Train: 0.9268 - Val: 0.5488 (acc 0.607)
#   New best model saved at epoch 124
# Epoch 125 SupCon Train Loss: 0.9234
# Epoch 125 PairEval Acc: 0.6028  (loss 0.5380)
# Epoch 125/200 - LR: 0.001000 - Train: 0.9234 - Val: 0.5380 (acc 0.603)
# Epoch 126 SupCon Train Loss: 0.9291
# Epoch 126 PairEval Acc: 0.5966  (loss 0.5541)
# Epoch 126/200 - LR: 0.001000 - Train: 0.9291 - Val: 0.5541 (acc 0.597)
# Epoch 127 SupCon Train Loss: 0.9212
# Epoch 127 PairEval Acc: 0.6029  (loss 0.5356)
# Epoch 127/200 - LR: 0.001000 - Train: 0.9212 - Val: 0.5356 (acc 0.603)
# Epoch 128 SupCon Train Loss: 0.9224
# Epoch 128 PairEval Acc: 0.6028  (loss 0.5437)
# Epoch 128/200 - LR: 0.001000 - Train: 0.9224 - Val: 0.5437 (acc 0.603)
# Epoch 129 SupCon Train Loss: 0.9164
# Epoch 129 PairEval Acc: 0.6012  (loss 0.5415)
# Epoch 129/200 - LR: 0.001000 - Train: 0.9164 - Val: 0.5415 (acc 0.601)
# Epoch 130 SupCon Train Loss: 0.9200
# Epoch 130 PairEval Acc: 0.5999  (loss 0.5394)
# Epoch 130/200 - LR: 0.001000 - Train: 0.9200 - Val: 0.5394 (acc 0.600)
# Epoch 131 SupCon Train Loss: 0.9107
# Epoch 131 PairEval Acc: 0.6069  (loss 0.5411)
# Epoch 131/200 - LR: 0.001000 - Train: 0.9107 - Val: 0.5411 (acc 0.607)
#   New best model saved at epoch 131
# Epoch 132 SupCon Train Loss: 0.9112
# Epoch 132 PairEval Acc: 0.6061  (loss 0.5533)
# Epoch 132/200 - LR: 0.001000 - Train: 0.9112 - Val: 0.5533 (acc 0.606)
# Epoch 133 SupCon Train Loss: 0.9145
# Epoch 133 PairEval Acc: 0.5970  (loss 0.5452)
# Epoch 133/200 - LR: 0.001000 - Train: 0.9145 - Val: 0.5452 (acc 0.597)
# Epoch 134 SupCon Train Loss: 0.9109
# Epoch 134 PairEval Acc: 0.6131  (loss 0.5342)
# Epoch 134/200 - LR: 0.001000 - Train: 0.9109 - Val: 0.5342 (acc 0.613)
#   New best model saved at epoch 134
# Epoch 135 SupCon Train Loss: 0.9064
# Epoch 135 PairEval Acc: 0.6043  (loss 0.5448)
# Epoch 135/200 - LR: 0.001000 - Train: 0.9064 - Val: 0.5448 (acc 0.604)
# Epoch 136 SupCon Train Loss: 0.9040
# Epoch 136 PairEval Acc: 0.5963  (loss 0.5638)
# Epoch 136/200 - LR: 0.001000 - Train: 0.9040 - Val: 0.5638 (acc 0.596)
# Epoch 137 SupCon Train Loss: 0.9025
# Epoch 137 PairEval Acc: 0.6074  (loss 0.5252)
# Epoch 137/200 - LR: 0.001000 - Train: 0.9025 - Val: 0.5252 (acc 0.607)
# Epoch 138 SupCon Train Loss: 0.9049
# Epoch 138 PairEval Acc: 0.6103  (loss 0.5359)
# Epoch 138/200 - LR: 0.001000 - Train: 0.9049 - Val: 0.5359 (acc 0.610)
# Epoch 139 SupCon Train Loss: 0.9010
# Epoch 139 PairEval Acc: 0.6087  (loss 0.5341)
# Epoch 139/200 - LR: 0.001000 - Train: 0.9010 - Val: 0.5341 (acc 0.609)
# Epoch 140 SupCon Train Loss: 0.9021
# Epoch 140 PairEval Acc: 0.6053  (loss 0.5205)
# Epoch 140/200 - LR: 0.001000 - Train: 0.9021 - Val: 0.5205 (acc 0.605)
# Epoch 141 SupCon Train Loss: 0.8998
# Epoch 141 PairEval Acc: 0.6006  (loss 0.5469)
# Epoch 141/200 - LR: 0.001000 - Train: 0.8998 - Val: 0.5469 (acc 0.601)
# Epoch 142 SupCon Train Loss: 0.9001
# Epoch 142 PairEval Acc: 0.6083  (loss 0.5396)
# Epoch 142/200 - LR: 0.001000 - Train: 0.9001 - Val: 0.5396 (acc 0.608)
# Epoch 143 SupCon Train Loss: 0.9026
# Epoch 143 PairEval Acc: 0.6066  (loss 0.5497)
# Epoch 143/200 - LR: 0.001000 - Train: 0.9026 - Val: 0.5497 (acc 0.607)
# Epoch 144 SupCon Train Loss: 0.8890
# Epoch 144 PairEval Acc: 0.6066  (loss 0.5292)
# Epoch 144/200 - LR: 0.001000 - Train: 0.8890 - Val: 0.5292 (acc 0.607)
# Epoch 145 SupCon Train Loss: 0.8907
# Epoch 145 PairEval Acc: 0.6080  (loss 0.5367)
# Epoch 145/200 - LR: 0.001000 - Train: 0.8907 - Val: 0.5367 (acc 0.608)
# Epoch 146 SupCon Train Loss: 0.8925
# Epoch 146 PairEval Acc: 0.5996  (loss 0.5725)
# Epoch 146/200 - LR: 0.001000 - Train: 0.8925 - Val: 0.5725 (acc 0.600)
# Epoch 147 SupCon Train Loss: 0.8885
# Epoch 147 PairEval Acc: 0.6067  (loss 0.5569)
# Epoch 147/200 - LR: 0.001000 - Train: 0.8885 - Val: 0.5569 (acc 0.607)
# Epoch 148 SupCon Train Loss: 0.8857
# Epoch 148 PairEval Acc: 0.6173  (loss 0.5359)
# Epoch 148/200 - LR: 0.001000 - Train: 0.8857 - Val: 0.5359 (acc 0.617)
#   New best model saved at epoch 148
# Epoch 149 SupCon Train Loss: 0.8878
# Epoch 149 PairEval Acc: 0.6015  (loss 0.5659)
# Epoch 149/200 - LR: 0.001000 - Train: 0.8878 - Val: 0.5659 (acc 0.601)
# Epoch 150 SupCon Train Loss: 0.8842
# Epoch 150 PairEval Acc: 0.6048  (loss 0.5390)
# Epoch 150/200 - LR: 0.001000 - Train: 0.8842 - Val: 0.5390 (acc 0.605)
# Epoch 151 SupCon Train Loss: 0.8878
# Epoch 151 PairEval Acc: 0.6014  (loss 0.5416)
# Epoch 151/200 - LR: 0.001000 - Train: 0.8878 - Val: 0.5416 (acc 0.601)
# Epoch 152 SupCon Train Loss: 0.8862
# Epoch 152 PairEval Acc: 0.6051  (loss 0.5470)
# Epoch 152/200 - LR: 0.001000 - Train: 0.8862 - Val: 0.5470 (acc 0.605)
# Epoch 153 SupCon Train Loss: 0.8820
# Epoch 153 PairEval Acc: 0.6040  (loss 0.5607)
# Epoch 153/200 - LR: 0.001000 - Train: 0.8820 - Val: 0.5607 (acc 0.604)
# Epoch 154 SupCon Train Loss: 0.8842
# Epoch 154 PairEval Acc: 0.6096  (loss 0.5417)
# Epoch 154/200 - LR: 0.001000 - Train: 0.8842 - Val: 0.5417 (acc 0.610)
# Epoch 155 SupCon Train Loss: 0.8813
# Epoch 155 PairEval Acc: 0.5993  (loss 0.5626)
# Epoch 155/200 - LR: 0.001000 - Train: 0.8813 - Val: 0.5626 (acc 0.599)
# Epoch 156 SupCon Train Loss: 0.8780
# Epoch 156 PairEval Acc: 0.6152  (loss 0.5409)
# Epoch 156/200 - LR: 0.001000 - Train: 0.8780 - Val: 0.5409 (acc 0.615)
# Epoch 157 SupCon Train Loss: 0.8784
# Epoch 157 PairEval Acc: 0.6070  (loss 0.5516)
# Epoch 157/200 - LR: 0.001000 - Train: 0.8784 - Val: 0.5516 (acc 0.607)
# Epoch 158 SupCon Train Loss: 0.8758
# Epoch 158 PairEval Acc: 0.6061  (loss 0.5450)
# Epoch 158/200 - LR: 0.001000 - Train: 0.8758 - Val: 0.5450 (acc 0.606)
# Epoch 159 SupCon Train Loss: 0.8788
# Epoch 159 PairEval Acc: 0.6124  (loss 0.5388)
# Epoch 159/200 - LR: 0.001000 - Train: 0.8788 - Val: 0.5388 (acc 0.612)
# Epoch 160 SupCon Train Loss: 0.8742
# Epoch 160 PairEval Acc: 0.6034  (loss 0.5459)
# Epoch 160/200 - LR: 0.001000 - Train: 0.8742 - Val: 0.5459 (acc 0.603)
# Epoch 161 SupCon Train Loss: 0.8707
# Epoch 161 PairEval Acc: 0.6122  (loss 0.5244)
# Epoch 161/200 - LR: 0.001000 - Train: 0.8707 - Val: 0.5244 (acc 0.612)
# Epoch 162 SupCon Train Loss: 0.8752
# Epoch 162 PairEval Acc: 0.6085  (loss 0.5438)
# Epoch 162/200 - LR: 0.001000 - Train: 0.8752 - Val: 0.5438 (acc 0.608)
# Epoch 163 SupCon Train Loss: 0.8693
# Epoch 163 PairEval Acc: 0.6038  (loss 0.5414)
# Epoch 163/200 - LR: 0.001000 - Train: 0.8693 - Val: 0.5414 (acc 0.604)
# Epoch 164 SupCon Train Loss: 0.8702
# Epoch 164 PairEval Acc: 0.6080  (loss 0.5349)
# Epoch 164/200 - LR: 0.001000 - Train: 0.8702 - Val: 0.5349 (acc 0.608)
# Epoch 165 SupCon Train Loss: 0.8665
# Epoch 165 PairEval Acc: 0.6143  (loss 0.5492)
# Epoch 165/200 - LR: 0.001000 - Train: 0.8665 - Val: 0.5492 (acc 0.614)
# Epoch 166 SupCon Train Loss: 0.8721
# Epoch 166 PairEval Acc: 0.6173  (loss 0.5329)
# Epoch 166/200 - LR: 0.001000 - Train: 0.8721 - Val: 0.5329 (acc 0.617)
# Epoch 167 SupCon Train Loss: 0.8649
# Epoch 167 PairEval Acc: 0.6169  (loss 0.5229)
# Epoch 167/200 - LR: 0.001000 - Train: 0.8649 - Val: 0.5229 (acc 0.617)
# Epoch 168 SupCon Train Loss: 0.8622
# Epoch 168 PairEval Acc: 0.6104  (loss 0.5475)
# Epoch 168/200 - LR: 0.001000 - Train: 0.8622 - Val: 0.5475 (acc 0.610)
# Epoch 169 SupCon Train Loss: 0.8655
# Epoch 169 PairEval Acc: 0.6197  (loss 0.5249)
# Epoch 169/200 - LR: 0.001000 - Train: 0.8655 - Val: 0.5249 (acc 0.620)
#   New best model saved at epoch 169
# Epoch 170 SupCon Train Loss: 0.8631
# Epoch 170 PairEval Acc: 0.6197  (loss 0.5202)
# Epoch 170/200 - LR: 0.001000 - Train: 0.8631 - Val: 0.5202 (acc 0.620)
# Epoch 171 SupCon Train Loss: 0.8668
# Epoch 171 PairEval Acc: 0.6170  (loss 0.5282)
# Epoch 171/200 - LR: 0.001000 - Train: 0.8668 - Val: 0.5282 (acc 0.617)
# Epoch 172 SupCon Train Loss: 0.8619
# Epoch 172 PairEval Acc: 0.6195  (loss 0.5160)
# Epoch 172/200 - LR: 0.001000 - Train: 0.8619 - Val: 0.5160 (acc 0.620)
# Epoch 173 SupCon Train Loss: 0.8582
# Epoch 173 PairEval Acc: 0.6099  (loss 0.5380)
# Epoch 173/200 - LR: 0.001000 - Train: 0.8582 - Val: 0.5380 (acc 0.610)
# Epoch 174 SupCon Train Loss: 0.8585
# Epoch 174 PairEval Acc: 0.6162  (loss 0.5386)
# Epoch 174/200 - LR: 0.001000 - Train: 0.8585 - Val: 0.5386 (acc 0.616)
# Epoch 175 SupCon Train Loss: 0.8551
# Epoch 175 PairEval Acc: 0.6115  (loss 0.5448)
# Epoch 175/200 - LR: 0.001000 - Train: 0.8551 - Val: 0.5448 (acc 0.611)
# Epoch 176 SupCon Train Loss: 0.8562
# Epoch 176 PairEval Acc: 0.6116  (loss 0.5410)
# Epoch 176/200 - LR: 0.001000 - Train: 0.8562 - Val: 0.5410 (acc 0.612)
# Epoch 177 SupCon Train Loss: 0.8629
# Epoch 177 PairEval Acc: 0.6143  (loss 0.5315)
# Epoch 177/200 - LR: 0.001000 - Train: 0.8629 - Val: 0.5315 (acc 0.614)
# Epoch 178 SupCon Train Loss: 0.8564
# Epoch 178 PairEval Acc: 0.6180  (loss 0.5336)
# Epoch 178/200 - LR: 0.001000 - Train: 0.8564 - Val: 0.5336 (acc 0.618)
# Epoch 179 SupCon Train Loss: 0.8540
# Epoch 179 PairEval Acc: 0.6072  (loss 0.5489)
# Epoch 179/200 - LR: 0.001000 - Train: 0.8540 - Val: 0.5489 (acc 0.607)
# Epoch 180 SupCon Train Loss: 0.8532
# Epoch 180 PairEval Acc: 0.6159  (loss 0.5300)
# Epoch 180/200 - LR: 0.001000 - Train: 0.8532 - Val: 0.5300 (acc 0.616)
# Epoch 181 SupCon Train Loss: 0.8525
# Epoch 181 PairEval Acc: 0.6208  (loss 0.5101)
# Epoch 181/200 - LR: 0.001000 - Train: 0.8525 - Val: 0.5101 (acc 0.621)
#   New best model saved at epoch 181
# Epoch 182 SupCon Train Loss: 0.8551
# Epoch 182 PairEval Acc: 0.6089  (loss 0.5333)
# Epoch 182/200 - LR: 0.001000 - Train: 0.8551 - Val: 0.5333 (acc 0.609)
# Epoch 183 SupCon Train Loss: 0.8478
# Epoch 183 PairEval Acc: 0.6153  (loss 0.5325)
# Epoch 183/200 - LR: 0.001000 - Train: 0.8478 - Val: 0.5325 (acc 0.615)
# Epoch 184 SupCon Train Loss: 0.8477
# Epoch 184 PairEval Acc: 0.6187  (loss 0.5314)
# Epoch 184/200 - LR: 0.001000 - Train: 0.8477 - Val: 0.5314 (acc 0.619)
# Epoch 185 SupCon Train Loss: 0.8471
# Epoch 185 PairEval Acc: 0.6187  (loss 0.5294)
# Epoch 185/200 - LR: 0.001000 - Train: 0.8471 - Val: 0.5294 (acc 0.619)
# Epoch 186 SupCon Train Loss: 0.8486
# Epoch 186 PairEval Acc: 0.6195  (loss 0.5272)
# Epoch 186/200 - LR: 0.001000 - Train: 0.8486 - Val: 0.5272 (acc 0.619)
# Epoch 187 SupCon Train Loss: 0.8495
# Epoch 187 PairEval Acc: 0.6128  (loss 0.5184)
# Epoch 187/200 - LR: 0.001000 - Train: 0.8495 - Val: 0.5184 (acc 0.613)
# Epoch 188 SupCon Train Loss: 0.8490
# Epoch 188 PairEval Acc: 0.6210  (loss 0.5220)
# Epoch 188/200 - LR: 0.001000 - Train: 0.8490 - Val: 0.5220 (acc 0.621)
#   New best model saved at epoch 188
# Epoch 189 SupCon Train Loss: 0.8445
# Epoch 189 PairEval Acc: 0.6085  (loss 0.5313)
# Epoch 189/200 - LR: 0.001000 - Train: 0.8445 - Val: 0.5313 (acc 0.608)
# Epoch 190 SupCon Train Loss: 0.8449
# Epoch 190 PairEval Acc: 0.6241  (loss 0.5184)
# Epoch 190/200 - LR: 0.001000 - Train: 0.8449 - Val: 0.5184 (acc 0.624)
#   New best model saved at epoch 190
# Epoch 191 SupCon Train Loss: 0.8505
# Epoch 191 PairEval Acc: 0.6153  (loss 0.5209)
# Epoch 191/200 - LR: 0.001000 - Train: 0.8505 - Val: 0.5209 (acc 0.615)
# Epoch 192 SupCon Train Loss: 0.8497
# Epoch 192 PairEval Acc: 0.6225  (loss 0.5192)
# Epoch 192/200 - LR: 0.001000 - Train: 0.8497 - Val: 0.5192 (acc 0.622)
# Epoch 193 SupCon Train Loss: 0.8384
# Epoch 193 PairEval Acc: 0.6255  (loss 0.5301)
# Epoch 193/200 - LR: 0.001000 - Train: 0.8384 - Val: 0.5301 (acc 0.626)
#   New best model saved at epoch 193
# Epoch 194 SupCon Train Loss: 0.8395
# Epoch 194 PairEval Acc: 0.6190  (loss 0.5186)
# Epoch 194/200 - LR: 0.001000 - Train: 0.8395 - Val: 0.5186 (acc 0.619)
# Epoch 195 SupCon Train Loss: 0.8340
# Epoch 195 PairEval Acc: 0.6210  (loss 0.5285)
# Epoch 195/200 - LR: 0.001000 - Train: 0.8340 - Val: 0.5285 (acc 0.621)
# Epoch 196 SupCon Train Loss: 0.8376
# Epoch 196 PairEval Acc: 0.6207  (loss 0.5130)
# Epoch 196/200 - LR: 0.001000 - Train: 0.8376 - Val: 0.5130 (acc 0.621)
# Epoch 197 SupCon Train Loss: 0.8393
# Epoch 197 PairEval Acc: 0.6175  (loss 0.5235)
# Epoch 197/200 - LR: 0.001000 - Train: 0.8393 - Val: 0.5235 (acc 0.618)
# Epoch 198 SupCon Train Loss: 0.8337
# Epoch 198 PairEval Acc: 0.6167  (loss 0.5233)
# Epoch 198/200 - LR: 0.001000 - Train: 0.8337 - Val: 0.5233 (acc 0.617)
# Epoch 199 SupCon Train Loss: 0.8319
# Epoch 199 PairEval Acc: 0.6235  (loss 0.5247)
# Epoch 199/200 - LR: 0.001000 - Train: 0.8319 - Val: 0.5247 (acc 0.623)
# Epoch 200 SupCon Train Loss: 0.8371
# Epoch 200 PairEval Acc: 0.6176  (loss 0.5220)
# Epoch 200/200 - LR: 0.001000 - Train: 0.8371 - Val: 0.5220 (acc 0.618)
# Extracting embeddings...
# Extracting embeddings...
# STN: 13930 segments
# VO: 10404 segments
# GPi: 31425 segments
# VIM: 6728 segments
# VA: 8207 segments
# PPN: 9129 segments
# SNR: 3827 segments
# Computing clustering metrics...
# Generating and saving confusion matrices...
# ✅ Confusion matrix saved to: data\multi_subject_training\MSC_model\cm_val.png
# ✅ Confusion matrix saved to: data\multi_subject_training\MSC_model\cm_test.png
# ✅ Confusion matrix saved to: data\multi_subject_training\MSC_model\cm_heldout.png
# ✅ Evaluation saved to results\multi_subject\evaluation_summary_multi_subject.xlsx
